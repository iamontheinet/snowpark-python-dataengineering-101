# %% [markdown]
# # Transforming and Processing Amazon Reviews in Snowflake using Snowpark for Python
#
# #### Overview:
#
# * Import Python Libraries
# * Estabish Secure Connetion to Snowflake using AWS Secrets Manager
# * Exploratory Data Analysis using Snowpark DataFrames
#   * Load data into Snowpark DataFrames
#     * Movies and TV reviews
#     * Musical Instruments Reviews
# * Snowpark DataFrame Actions and Transformations
#   * Access Semi-structured Data using Snowpark DataFrame API
#   * Combine Movies & TV with Musical Instruments Reviews
#   * Replace Missing Values for REVIEWTEXT column with "Not available"
# * Snowpark Python User-Defined Function (UDF)
#   * (Simple) Create and Register UDF named "to_lowercase"
#   * Call "to_lowercase" UDF on "SUMMARY" column in Snowpark DataFrame
#   * (Complex) Create and Register Natural Language Processing (NLP) UDF using spaCy and BeautifulSoup
#   * Call NLP UDF on column "REVIEWTEXT" in Snowpark DataFrame to tokenize Amazon Reviews
# * (Scaling) Snowpark Python Stored Procedure (SP)
#   * Create Python Function to Transform Data
#   * Register Python Function as Snowpark Stored Procedure to Deploy Code to Snowflake
#   * Execute Snowpark Stored Procedure to Transform Data on Snowflake
#   * Examine Results - Reviews and Tokens
#
# *Data Source: https://cseweb.ucsd.edu/~jmcauley/datasets/amazon_v2/*

# %% [markdown]
# ### Import Python Libraries

# %%
# Snowpark
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import PandasSeries, PandasDataFrame, Variant
from snowflake.snowpark.functions import udf,count,col,lit,call_udf,sproc,json_extract_path_text
from snowflake.snowpark.version import VERSION

# Misc
import pandas as pd
import json
from cachetools import cached
import logging 
logger = logging.getLogger("snowflake.snowpark.session")
logger.setLevel(logging.ERROR)

# For AWS Secrets Manager
import boto3
from botocore.exceptions import ClientError

# %% [markdown]
# ### Establish Secure Connection to Snowflake using AWS Secrets Manager
#
# *NOTE: Other options include loading credentials from a file (for example, connection.json), Okta, SSO, MFA*

# %%
# Load Snowflake connection details from AWS Secrets Manager
def get_aws_sf_connection_details(secret_name,region_name):
    
    # Create a Secrets Manager boto3 client
    boto3_session = boto3.session.Session()
    client = boto3_session.client(service_name='secretsmanager',region_name=region_name)
    
    get_secret_value_response = None

    try:
        # Get secret values(s) based on the passed in secret name
        get_secret_value_response = client.get_secret_value(SecretId=secret_name)['SecretString']
    except ClientError as e:
        if e.response['Error']['Code'] == 'DecryptionFailureException':
            # Secrets Manager can't decrypt the protected secret text using the provided KMS key.
            raise e
        elif e.response['Error']['Code'] == 'InternalServiceErrorException':
            # An error occurred on the server side.
            raise e
        elif e.response['Error']['Code'] == 'InvalidParameterException':
            # You provided an invalid value for a parameter.
            raise e
        elif e.response['Error']['Code'] == 'InvalidRequestException':
            # You provided a parameter value that is not valid for the current state of the resource.
            raise e
        elif e.response['Error']['Code'] == 'ResourceNotFoundException':
            # We can't find the resource that you asked for.
            raise e

    return get_secret_value_response
        
# Create Snowflake Session object
connection_parameters = json.loads(get_aws_sf_connection_details('dash-sfdevrel-connection','us-west-2'))
connection_parameters['warehouse'] = 'DASH_6XL'
session = Session.builder.configs(connection_parameters).create()

snowpark_version_major,snowpark_version_minor,snowpark_version_patch = VERSION[0],VERSION[1],VERSION[2]

# Current Environment Details
print('Database                    : {}'.format(session.get_current_database()))
print('Schema                      : {}'.format(session.get_current_schema()))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version_major,snowpark_version_minor,snowpark_version_patch))
# Out:
# Database                    : "DASH_DB"
# Schema                      : "DASH_SCHEMA"
# Snowpark for Python version : 1.0.0

# %% [markdown]
# ### Load Data into Snowpark DataFrames

# %% [markdown]
# ##### Movies & TV Reviews

# %%
df_amazon_reviews_movies = session.table('amazon_reviews_movies')
df_amazon_reviews_movies.show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"OVERALL"  |"VERIFIED"  |"REVIEWTIME"  |"REVIEWERID"    |"ASIN"      |"STYLE"                         |"REVIEWERNAME"   |"REVIEWTEXT"                                        |"SUMMARY"                                           |"UNIXREVIEWTIME"  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |4          |True        |03 30, 2015   |A2XPYGJK9M61K   |B005KR6O1C  |"{'Format:': ' DVD'}"           |JHDScot          |Forget the corny storyline and sappy lyrics. If...  |A musical send-up of the original                   |1427673600        |
# |1          |True        |03 21, 2015   |A1FUPXIAFT9XK1  |B005KR6O1C  |"{'Format:': ' DVD'}"           |Lois Jacobson    |Love it                                             |One Star                                            |1426896000        |
# |5          |True        |11 30, 2014   |A309UH3MW426Q2  |B005KR6NNG  |"{'Format:': ' Amazon Video'}"  |Kindle Customer  |Awesome!!!                                          |Five Stars                                          |1417305600        |
# |5          |True        |11 29, 2014   |A149G89VY5AOIU  |B005KR6NNG  |"{'Format:': ' Amazon Video'}"  |Amazon Customer  |I thought the play was absolutely awesome! It i...  |I thought the play was absolutely awesome! It i...  |1417219200        |
# |3          |True        |11 29, 2014   |A2SYBXKNJSQNU4  |B005KR6NNG  |"{'Format:': ' Amazon Video'}"  |randy            |Ok for a Christmas play                             |Three Stars                                         |1417219200        |
# |4          |True        |11 25, 2014   |A2U5GBB2M626SD  |B005KR6NNG  |"{'Format:': ' Amazon Video'}"  |KAREN GUERRERO   |We have always enjoyed Mr. Perry's movies. His ...  |Love, love, love Madea!                             |1416873600        |
# |5          |True        |11 21, 2014   |A1Y942BLWX14W   |B005KR6NNG  |"{'Format:': ' Amazon Video'}"  |Susan Douan      |ITS TYLER PERRY!!! NEED I SAY MORE??? LOVED IT!!!   |LOVED IT!                                           |1416528000        |
# |5          |True        |11 12, 2014   |A14TM2SEENPZ4K  |B005KR6NNG  |"{'Format:': ' DVD'}"           |Lois             |I love Tyler Perry's movie A Madea Christmas        |Five Stars                                          |1415750400        |
# |1          |True        |11 10, 2014   |AGCIRXISCBCHA   |B005KR6NNG  |"{'Format:': ' DVD'}"           |Gary Clark       |Sent it back  its a play don't like                 |Sent it back its a play dont                        |1415577600        |
# |5          |True        |11 9, 2014    |A3B01SLD8OF3AL  |B005KR6NNG  |"{'Format:': ' DVD'}"           |Deborah Smith    |The movie A Madea's Christmas:The Play is excel...  |The Play is excellent.                              |1415491200        |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Musical Instruments Reviews

# %%
df_amazon_reviews_musical_inst = session.table('amazon_reviews_musical_instruments')
df_amazon_reviews_musical_inst.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"OVERALL"  |"VERIFIED"  |"REVIEWTIME"  |"REVIEWERID"    |"ASIN"      |"STYLE"  |"REVIEWERNAME"       |"REVIEWTEXT"                                        |"SUMMARY"                                           |"UNIXREVIEWTIME"  |
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |5          |true        |07 7, 2018    |A5NUSGGKE1BNB   |B01H7N27L2  |NULL     |Mason                |Perfect fit and comfortable. Nice pocket placem...  |Great saddle, just what i needed                    |1530921600        |
# |5          |true        |03 15, 2018   |A3ELFQ6XR2RBPH  |B01H7N27L2  |NULL     |Brian C. Hagerty     |This is a very comfortable seat and provides ni...  |Sturdy, comfortable, and convenient. A very nic...  |1521072000        |
# |2          |true        |02 9, 2018    |A1WW6RC4PTVNGA  |B01H7N27L2  |NULL     |David L.             |Overpriced for what it is.  It comes with nothi...  |Overpriced for what it is. It comes with nothin...  |1518134400        |
# |4          |true        |12 5, 2017    |ARNSI65BQSM5    |B01H7N27L2  |NULL     |Kevin                |Its good, but the cushion doesnt actually provi...  |Its good, but the cushion doesnt actually provi...  |1512432000        |
# |4          |true        |08 6, 2017    |A20FKK2S0ENBW1  |B01H7N27L2  |NULL     |Matt Ehrenzeller     |Your butt will thank you. It does muffle the so...  |Four Stars                                          |1501977600        |
# |5          |true        |05 26, 2017   |A11ULYDX46WOXB  |B01H7N27L2  |NULL     |Nilo Moriconi        |good                                                |Five Stars                                          |1495756800        |
# |5          |true        |04 8, 2017    |A8MVQVBE3P0K5   |B01H7N27L2  |NULL     |Matthew J Harradine  |Love it. I have a cabasa velcroed to one side a...  |Love it. I have a cabasa velcroed to one ...        |1491609600        |
# |4          |false       |01 24, 2017   |ATKT6ZO4JT7BX   |B01H7N27L2  |NULL     |jgscroggins          |The saddle is a much needed accessory to the wo...  |Great accessory; needs firmer padding...            |1485216000        |
# |           |            |              |                |            |         |                     |                                                    |                                                    |                  |
# |           |            |              |                |            |         |                     |I really like the velcro sides. The entire "bla...  |                                                    |                  |
# |           |            |              |                |            |         |                     |                                                    |                                                    |                  |
# |           |            |              |                |            |         |                     |My only concern is the durability of the paddin...  |                                                    |                  |
# |5          |true        |12 28, 2016   |A22VV5OKYSN1HF  |B01H7N27L2  |NULL     |Amazon Customer      |Great product.                                      |Five Stars                                          |1482883200        |
# |5          |true        |12 22, 2016   |AHSBMY0HCIDKO   |B01H7N27L2  |NULL     |guy giusto           |This is a very nice accessory for my lp string ...  |This is a very nice accessory for my lp string ...  |1482364800        |
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Snowpark DataFrame Actions and Transformations

# %% [markdown]
# ##### Access Semi-structured Data using Snowpark DataFrame API

# %%
df_amazon_reviews_movies.select(json_extract_path_text(col('STYLE'), lit('"Format:"')).alias('VALUE')).show(20)
# Out:
# -----------
# |"VALUE"  |
# -----------
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# -----------

# %% [markdown]
# ##### Combine Movies & TV with Musical Instruments Reviews

# %%
df_amazon_reviews_all = df_amazon_reviews_musical_inst.union(df_amazon_reviews_movies)
df_amazon_reviews_all.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"OVERALL"  |"VERIFIED"  |"REVIEWTIME"  |"REVIEWERID"    |"ASIN"      |"STYLE"                         |"REVIEWERNAME"         |"REVIEWTEXT"                                        |"SUMMARY"                                       |"UNIXREVIEWTIME"  |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |5          |true        |01 18, 2016   |A19KX4C21272OL  |B004M8UZ3S  |NULL                            |Tayler McFarland       |Love this controller! Save so much space with it.   |Small and easy to use. Feels awesome!           |1453075200        |
# |1          |true        |09 13, 2016   |A3EZ0LFEW6O6T4  |B004M8UZ3S  |NULL                            |W. L. minton           |This review is for the NanoKey2- Please read th...  |The Award for WORST midi controller goes to...  |1473724800        |
# |           |            |              |                |            |                                |                       |Worst keys for a midi keyboard I've ever had, H...  |                                                |                  |
# |           |            |              |                |            |                                |                       | I just wanted something inexpensive to travel ...  |                                                |                  |
# |4          |True        |05 14, 2016   |A3RD732Y62DY4A  |B00005JLBE  |"{'Format:': ' Amazon Video'}"  |EWJ                    |Very nice Bond movie. It is by far Brosnan's be...  |Brosnan's best Bond.                            |1463184000        |
# |5          |false       |09 1, 2015    |A6F2JH79QDCC8   |B005DGIUYE  |NULL                            |barbara k. harrington  |Great!  Fits inside my flute bag without adding...  |Lightweight and convenient                      |1441065600        |
# |5          |True        |10 26, 2014   |A2V8VBDNRT49AW  |B000WMA6H8  |"{'Format:': ' DVD'}"           |holly                  |good deal                                           |Five Stars                                      |1414281600        |
# |5          |True        |04 11, 2015   |A16AI8K5E2SNR7  |6304392907  |"{'Format:': ' DVD'}"           |Charles Woodbury       |Great Item, Fast delivery                           |Five Stars                                      |1428710400        |
# |5          |True        |11 6, 2013    |A1S0YLGWW75HIH  |B000067A8U  |"{'Format:': ' DVD'}"           |yorkie                 |For any Brit this is a MUST especially if you g...  |Fun great laughs                                |1383696000        |
# |3          |true        |01 27, 2017   |A1PSB002SR9XWD  |B01733ZK9M  |NULL                            |S. Gabeler             |The V12 on the card was supposed  to be a 3 and...  |Great idea, but wrong reed was on the card      |1485475200        |
# |3          |true        |11 12, 2015   |A15JR04AA2PK1F  |B00F0W9PAO  |NULL                            |Shinobo                |Arrived with the case cracked. The moon gel was...  |Three Stars                                     |1447286400        |
# |1          |true        |03 24, 2017   |AOWMUFLGB10QH   |B00H40VYPY  |NULL                            |Max                    |dead and very difficult to install                  |dead and very difficult to install              |1490313600        |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(f"Total Movies & TV reviews         :",df_amazon_reviews_movies.count())
print(f"Total Musical Instruments reviews :",df_amazon_reviews_musical_inst.count())
print(f"Total reviews                     :",df_amazon_reviews_all.count())
# Out:
# Total Movies & TV reviews         : 8765580
# Total Musical Instruments reviews : 1512530
# Total reviews                     : 10003402

# %% [markdown]
# ##### Replace Missing Values for REVIEWTEXT column with "Not available"

# %%
null_cnt = df_amazon_reviews_all.filter(col("REVIEWTEXT").is_null()).count()
df_amazon_reviews_all = df_amazon_reviews_all.fillna('Not available',subset=["REVIEWTEXT"])
print(f"Number of records with missing REVIEWTEXT column filled with 'Not available':",null_cnt)
# Out:
# Number of records with missing REVIEWTEXT column filled with 'Not available': 8688

# %% [markdown]
# ### Snowpark Python User-Defined Function (UDF)

# %% [markdown]
# #### Create and Register UDF named "to_lowercase"

# %%
@udf(session=session,name='to_lowercase',replace=True,is_permanent=True,stage_location='@dash_udfs')
def to_lowercase(txt: str) -> str:
    return txt.lower()

# %% [markdown]
# #### Call "to_lowercase" UDF on "SUMMARY" column in Snowpark DataFrame

# %%
df_amazon_reviews_all.select("SUMMARY",call_udf('to_lowercase',col('SUMMARY')).as_('SUMMARY_LOWERCASE')).limit(10).show()
# Out:
# -------------------------------------------------------------------------------------------------
# |"SUMMARY"                                      |"SUMMARY_LOWERCASE"                            |
# -------------------------------------------------------------------------------------------------
# |Smaller than normal                            |smaller than normal                            |
# |Best show ever                                 |best show ever                                 |
# |DVD Series                                     |dvd series                                     |
# |Five Stars                                     |five stars                                     |
# |Absolutely awful                               |absolutely awful                               |
# |Five Stars                                     |five stars                                     |
# |Five Stars                                     |five stars                                     |
# |Foyle's War is great                           |foyle's war is great                           |
# |A Classic                                      |a classic                                      |
# |wow, thrilling movie with a surprising ending  |wow, thrilling movie with a surprising ending  |
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Create and Register Natural Language Processing (NLP) UDF using spaCy and BeautifulSoup

# %%
session.clear_imports()
session.add_import('@dash_udf_imports/en_core_web_sm.zip.gz')

@cached(cache={})
def load_en_core_web_sm(input_file,output_dir)-> object:
    import zipfile
    import spacy
    with zipfile.ZipFile(input_file, 'r') as zip_ref:
        zip_ref.extractall(output_dir)
    # load and return the english language small model of spacy
    nlp = spacy.load(output_dir + "/en_core_web_sm/en_core_web_sm-2.3.0")
    return nlp

@udf(session=session,packages=['spacy==2.3.5','beautifulsoup4','cachetools==4.2.2'],name='batch_nlp_tokenize_text',replace=True,is_permanent=True,stage_location='@dash_udfs')
def batch_nlp_tokenize_text(df: PandasDataFrame[str]) -> PandasSeries[list]:
    import os
    import sys
    import spacy
    from bs4 import BeautifulSoup 
    from spacy.tokenizer import Tokenizer
                       
    IMPORT_DIRECTORY_NAME = "snowflake_import_directory"
    import_dir = sys._xoptions[IMPORT_DIRECTORY_NAME]
    
    input_file = import_dir + 'en_core_web_sm.zip'
    output_dir = '/tmp/en_core_web_sm' + str(os.getpid())
    
    nlp = load_en_core_web_sm(input_file,output_dir)    
    tokenizer = Tokenizer(nlp.vocab)
    
    df.columns = ['REVIEWTEXT']

    # strip html
    df['REVIEWTEXT'] = df['REVIEWTEXT'].apply(lambda txt: BeautifulSoup(txt, "html.parser").get_text())
    
    # tokenize, lemmatize verbs and remove stop words
    df['TOKENS'] = df['REVIEWTEXT'].apply(lambda txt: [t.lemma_ for t in tokenizer(txt) if not t.is_stop])

    return df['TOKENS']

# %% [markdown]
# #### Call NLP UDF on column "REVIEWTEXT" in Snowpark DataFrame to tokenize Amazon Reviews

# %% [markdown]
# ##### Sample Size: 10 records

# %%
df_amazon_reviews_all.select('REVIEWTEXT',call_udf('batch_nlp_tokenize_text',col('REVIEWTEXT')).as_("TOKENS")).limit(10).show()
# Out:
# ---------------------------------------------------------------------------------
# |"REVIEWTEXT"                                        |"TOKENS"                  |
# ---------------------------------------------------------------------------------
# |If you are an old movie lover, this is one more...  |[                         |
# |                                                    |  "old",                  |
# |                                                    |  "movie",                |
# |                                                    |  "lover,",               |
# |                                                    |  "collection,",          |
# |                                                    |  "exceptions."           |
# |                                                    |]                         |
# |I almost always watch a film twice, even if I h...  |[                         |
# |"Basic" is a military murder mystery involving ...  |  "watch",                |
# |This is disappointing because we are talking a ...  |  "film",                 |
# |Maybe you will not be offended by the way it al...  |  "twice,",               |
# |                                                    |  "wait",                 |
# |                                                    |  "come",                 |
# |                                                    |  "video",                |
# |                                                    |  "DVD",                  |
# |                                                    |  "2",                    |
# |                                                    |  "viewing.",             |
# |                                                    |  " ",                    |
# |                                                    |  "distinctly",           |
# |                                                    |  "remember",             |
# |                                                    |  "aware",                |
# |                                                    |  "enjoy",                |
# |                                                    |  "watch",                |
# |                                                    |  "\"It's",               |
# |                                                    |  "Wonderful",            |
# |                                                    |  "Life\"",               |
# |                                                    |  "2",                    |
# |                                                    |  "time",                 |
# |                                                    |  "way",                  |
# |                                                    |  "Frank",                |
# |                                                    |  "Capra",                |
# |                                                    |  "set",                  |
# |                                                    |  "nightmare",            |
# |                                                    |  "sequence",             |
# |                                                    |  "end.",                 |
# |                                                    |  " ",                    |
# |                                                    |  "enjoy",                |
# |                                                    |  "watch",                |
# |                                                    |  "film",                 |
# |                                                    |  "2",                    |
# |                                                    |  "time",                 |
# |                                                    |  "appreciate",           |
# |                                                    |  "story",                |
# |                                                    |  "surprise",             |
# |                                                    |  "set",                  |
# |                                                    |  "up.",                  |
# |                                                    |  " ",                    |
# |                                                    |  "watch",                |
# |                                                    |  "\"Basic\"",            |
# |                                                    |  "look",                 |
# |                                                    |  "forward",              |
# |                                                    |  "2",                    |
# |                                                    |  "view",                 |
# |                                                    |  "appreciate",           |
# |                                                    |  "set",                  |
# |                                                    |  "dramatic",             |
# |                                                    |  "payoff",               |
# |                                                    |  "end.",                 |
# |                                                    |  " ",                    |
# |                                                    |  "Having",               |
# |                                                    |  "listen",               |
# |                                                    |  "John",                 |
# |                                                    |  "McTiernan",            |
# |                                                    |  "James",                |
# |                                                    |  "Vanderbilt",           |
# |                                                    |  "talk",                 |
# |                                                    |  "direct",               |
# |                                                    |  "write",                |
# |                                                    |  "\"Basic\"",            |
# |                                                    |  "want",                 |
# |                                                    |  "pay",                  |
# |                                                    |  "attention",            |
# |                                                    |  "set",                  |
# |                                                    |  "up,",                  |
# |                                                    |  "see",                  |
# |                                                    |  "end",                  |
# |                                                    |  "coming.",              |
# |                                                    |  " ",                    |
# |                                                    |  "finish",               |
# |                                                    |  "watch",                |
# |                                                    |  "film",                 |
# |                                                    |  "2",                    |
# |                                                    |  "time",                 |
# |                                                    |  "realize",              |
# |                                                    |  "depressing:",          |
# |                                                    |  "chance.",              |
# |                                                    |  " ",                    |
# |                                                    |  "hand",                 |
# |                                                    |  "like",                 |
# |                                                    |  "fact",                 |
# |                                                    |  "end",                  |
# |                                                    |  "coming;",              |
# |                                                    |  "hint",                 |
# |                                                    |  "point",                |
# |                                                    |  "resolution",           |
# |                                                    |  "feel",                 |
# |                                                    |  "tricked,",             |
# |                                                    |  "joy",                  |
# |                                                    |  "have",                 |
# |                                                    |  "played.",              |
# |                                                    |  "\n",                   |
# |                                                    |  "\"Basic\"",            |
# |                                                    |  "military",             |
# |                                                    |  "murder",               |
# |                                                    |  "mystery",              |
# |                                                    |  "involve",              |
# |                                                    |  "numb",                 |
# |                                                    |  "death",                |
# |                                                    |  "Rangers",              |
# |                                                    |  "train",                |
# |                                                    |  "exercise",             |
# |                                                    |  "rain",                 |
# |                                                    |  "soak",                 |
# |                                                    |  "jungle",               |
# |                                                    |  "Panama.",              |
# |                                                    |  " ",                    |
# |                                                    |  "Samuel",               |
# |                                                    |  "L.",                   |
# |                                                    |  "Jackson",              |
# |                                                    |  "play",                 |
# |                                                    |  "drill",                |
# |                                                    |  "sergeant",             |
# |                                                    |  "hell",                 |
# |                                                    |  "John",                 |
# |                                                    |  "Travolta",             |
# |                                                    |  "army",                 |
# |                                                    |  "officer",              |
# |                                                    |  "call",                 |
# |                                                    |  "investigate",          |
# |                                                    |  "old",                  |
# |                                                    |  "buddy.",               |
# |                                                    |  " ",                    |
# |                                                    |  "film",                 |
# |                                                    |  "compare",              |
# |                                                    |  "\"Memento\"",          |
# |                                                    |  "\"Rashomon,\"",        |
# |                                                    |  "comparison",           |
# |                                                    |  "faulty.",              |
# |                                                    |  " ",                    |
# |                                                    |  "\"Memento\"",          |
# |                                                    |  "brilliantly",          |
# |                                                    |  "construct",            |
# |                                                    |  "audience",             |
# |                                                    |  "understand",           |
# |                                                    |  "exactly",              |
# |                                                    |  "played.",              |
# |                                                    |  " ",                    |
# |                                                    |  "\"Basic\"",            |
# |                                                    |  "fooled,",              |
# |                                                    |  "tricked,",             |
# |                                                    |  "lie",                  |
# |                                                    |  "to.",                  |
# |                                                    |  " ",                    |
# |                                                    |  "\"Rashomon\"",         |
# |                                                    |  "different",            |
# |                                                    |  "character",            |
# |                                                    |  "tell",                 |
# |                                                    |  "decidedly",            |
# |                                                    |  "different",            |
# |                                                    |  "version",              |
# |                                                    |  "event,",               |
# |                                                    |  "certainly",            |
# |                                                    |  "key",                  |
# |                                                    |  "\"Basic,\"",           |
# |                                                    |  "film",                 |
# |                                                    |  "truth",                |
# |                                                    |  "end.",                 |
# |                                                    |  " ",                    |
# |                                                    |  "watch",                |
# |                                                    |  "\"Rashomon\"",         |
# |                                                    |  "2",                    |
# |                                                    |  "time",                 |
# |                                                    |  "understand",           |
# |                                                    |  "character",            |
# |                                                    |  "tell",                 |
# |                                                    |  "story",                |
# |                                                    |  "tell;",                |
# |                                                    |  "\"lies\"",             |
# |                                                    |  "\"self-deceptions\"",  |
# |                                                    |  "sense",                |
# |                                                    |  "present",              |
# |                                                    |  "teller",               |
# |                                                    |  "well",                 |
# |                                                    |  "light.",               |
# |                                                    |  " ",                    |
# |                                                    |  "\"Basic\"",            |
# |                                                    |  "lie",                  |
# |                                                    |  "intend",               |
# |                                                    |  "primarily",            |
# |                                                    |  "confuse",              |
# |                                                    |  "audience.",            |
# |                                                    |  " ",                    |
# |                                                    |  "do.",                  |
# |                                                    |  " ",                    |
# |                                                    |  "assume",               |
# |                                                    |  "tell",                 |
# |                                                    |  "tale",                 |
# |                                                    |  "close",                |
# |                                                    |  "truth,",               |
# |                                                    |  "knowledge",            |
# |                                                    |  "practical",            |
# |                                                    |  "good.",                |
# |                                                    |  "\n",                   |
# |                                                    |  "disappoint",           |
# |                                                    |  "talk",                 |
# |                                                    |  "movie",                |
# |                                                    |  "direct",               |
# |                                                    |  "McTiernan",            |
# |                                                    |  "star",                 |
# |                                                    |  "Travolta",             |
# |                                                    |  "Jackson",              |
# |                                                    |  "expect",               |
# |                                                    |  "better.",              |
# |                                                    |  " ",                    |
# |                                                    |  "However,",             |
# |                                                    |  "listen",               |
# |                                                    |  "interview",            |
# |                                                    |  "DVD",                  |
# |                                                    |  "happened.",            |
# |                                                    |  " ",                    |
# |                                                    |  "McTiernan",            |
# |                                                    |  "Travolta",             |
# |                                                    |  "impress",              |
# |                                                    |  "Vanderbilt's",         |
# |                                                    |  "script,",              |
# |                                                    |  "director",             |
# |                                                    |  "object",               |
# |                                                    |  "fate",                 |
# |                                                    |  "Jackson's",            |
# |                                                    |  "character",            |
# |                                                    |  "Travolta",             |
# |                                                    |  "happy",                |
# |                                                    |  "happen",               |
# |                                                    |  "character.",           |
# |                                                    |  " ",                    |
# |                                                    |  "Consequently,",        |
# |                                                    |  "2",                    |
# |                                                    |  "half",                 |
# |                                                    |  "script",               |
# |                                                    |  "rewrite",              |
# |                                                    |  "everybody",            |
# |                                                    |  "happy.",               |
# |                                                    |  " ",                    |
# |                                                    |  "However,",             |
# |                                                    |  "talk",                 |
# |                                                    |  "carefully",            |
# |                                                    |  "construct",            |
# |                                                    |  "murder",               |
# |                                                    |  "mystery,",             |
# |                                                    |  "sort",                 |
# |                                                    |  "revision",             |
# |                                                    |  "clearly",              |
# |                                                    |  "turn",                 |
# |                                                    |  "delicate",             |
# |                                                    |  "mechanism",            |
# |                                                    |  "cinematic",            |
# |                                                    |  "bulldozer.",           |
# |                                                    |  "\n",                   |
# |                                                    |  "Maybe",                |
# |                                                    |  "offend",               |
# |                                                    |  "way",                  |
# |                                                    |  "work",                 |
# |                                                    |  "out.",                 |
# |                                                    |  " ",                    |
# |                                                    |  "\"Basic\"",            |
# |                                                    |  "certainly",            |
# |                                                    |  "compelling,",          |
# |                                                    |  "way",                  |
# |                                                    |  "Travolta's",           |
# |                                                    |  "character",            |
# |                                                    |  "Tom",                  |
# |                                                    |  "Hardy",                |
# |                                                    |  "interrogate",          |
# |                                                    |  "witness",              |
# |                                                    |  "happen",               |
# |                                                    |  "jungle",               |
# |                                                    |  "Panama,",              |
# |                                                    |  "way",                  |
# |                                                    |  "banter",               |
# |                                                    |  "Captain",              |
# |                                                    |  "Osborne",              |
# |                                                    |  "(Connie",              |
# |                                                    |  "Nielsen),",            |
# |                                                    |  "young",                |
# |                                                    |  "officer",              |
# |                                                    |  "misfortune",           |
# |                                                    |  "close",                |
# |                                                    |  "thing",                |
# |                                                    |  "base",                 |
# |                                                    |  "investigative",        |
# |                                                    |  "officer.",             |
# |                                                    |  " ",                    |
# |                                                    |  "cast",                 |
# |                                                    |  "excellent,",           |
# |                                                    |  "Giovanni",             |
# |                                                    |  "Ribisi,",              |
# |                                                    |  "Taye",                 |
# |                                                    |  "Diggs,",               |
# |                                                    |  "Brian",                |
# |                                                    |  "Van",                  |
# |                                                    |  "Holt,",                |
# |                                                    |  "Tim",                  |
# |                                                    |  "Daly,",                |
# |                                                    |  "Harry",                |
# |                                                    |  "Connick,",             |
# |                                                    |  "Jr.",                  |
# |                                                    |  "run",                  |
# |                                                    |  "tangle",               |
# |                                                    |  "Travolta",             |
# |                                                    |  "Jackson.",             |
# |                                                    |  " ",                    |
# |                                                    |  "fair,",                |
# |                                                    |  "understand",           |
# |                                                    |  "badly",                |
# |                                                    |  "watch",                |
# |                                                    |  "film",                 |
# |                                                    |  "2",                    |
# |                                                    |  "time,",                |
# |                                                    |  "\"Basic\"",            |
# |                                                    |  "real",                 |
# |                                                    |  "thing",                |
# |                                                    |  "not."                  |
# |                                                    |]                         |
# |I Played the french horn in high school and wha...  |[                         |
# |                                                    |  "Played",               |
# |                                                    |  "french",               |
# |                                                    |  "horn",                 |
# |                                                    |  "high",                 |
# |                                                    |  "school",               |
# |                                                    |  "mistake",              |
# |                                                    |  "was.",                 |
# |                                                    |  "couldn't",             |
# |                                                    |  "jam",                  |
# |                                                    |  "myself,",              |
# |                                                    |  "day",                  |
# |                                                    |  "get",                  |
# |                                                    |  "idea",                 |
# |                                                    |  "play",                 |
# |                                                    |  "harmonica,",           |
# |                                                    |  "that's",               |
# |                                                    |  "wehre",                |
# |                                                    |  "gadget",               |
# |                                                    |  "come",                 |
# |                                                    |  "Play.",                |
# |                                                    |  "order",                |
# |                                                    |  "wait",                 |
# |                                                    |  "4-5",                  |
# |                                                    |  "days,",                |
# |                                                    |  "get",                  |
# |                                                    |  "it,",                  |
# |                                                    |  "tubed",                |
# |                                                    |  "play",                 |
# |                                                    |  "get",                  |
# |                                                    |  "jist",                 |
# |                                                    |  "things.",              |
# |                                                    |  "People",               |
# |                                                    |  "hear",                 |
# |                                                    |  "tell",                 |
# |                                                    |  "play",                 |
# |                                                    |  "it,",                  |
# |                                                    |  "freestyle,",           |
# |                                                    |  "did,",                 |
# |                                                    |  "know",                 |
# |                                                    |  "different",            |
# |                                                    |  "key",                  |
# |                                                    |  "sound",                |
# |                                                    |  "7",                    |
# |                                                    |  "day",                  |
# |                                                    |  "get",                  |
# |                                                    |  "it.",                  |
# |                                                    |  "Well,",                |
# |                                                    |  "think",                |
# |                                                    |  "suck",                 |
# |                                                    |  "people",               |
# |                                                    |  "tell",                 |
# |                                                    |  "sound",                |
# |                                                    |  "great",                |
# |                                                    |  "lot",                  |
# |                                                    |  "credit",               |
# |                                                    |  "they're",              |
# |                                                    |  "nice",                 |
# |                                                    |  "sound",                |
# |                                                    |  "good...",              |
# |                                                    |  "know,",                |
# |                                                    |  "ha",                   |
# |                                                    |  "ha,",                  |
# |                                                    |  "thats",                |
# |                                                    |  "fault.",               |
# |                                                    |  "Either-way,",          |
# |                                                    |  "harp",                 |
# |                                                    |  "great",                |
# |                                                    |  "harp",                 |
# |                                                    |  "beginner's.",          |
# |                                                    |  "week",                 |
# |                                                    |  "get",                  |
# |                                                    |  "it,",                  |
# |                                                    |  "key",                  |
# |                                                    |  "draw",                 |
# |                                                    |  "sound",                |
# |                                                    |  "like",                 |
# |                                                    |  "iron",                 |
# |                                                    |  "chair",                |
# |                                                    |  "drag",                 |
# |                                                    |  "floor....",            |
# |                                                    |  "soon",                 |
# |                                                    |  "3",                    |
# |                                                    |  "key",                  |
# |                                                    |  "draw",                 |
# |                                                    |  "go",                   |
# |                                                    |  "well...",              |
# |                                                    |  "3",                    |
# |                                                    |  "week",                 |
# |                                                    |  "eventually",           |
# |                                                    |  "notice",               |
# |                                                    |  "key",                  |
# |                                                    |  "get",                  |
# |                                                    |  "stick",                |
# |                                                    |  "blow",                 |
# |                                                    |  "hard",                 |
# |                                                    |  "past",                 |
# |                                                    |  "it.",                  |
# |                                                    |  "Remembering",          |
# |                                                    |  "cheap",                |
# |                                                    |  "harp,",                |
# |                                                    |  "help",                 |
# |                                                    |  "deal",                 |
# |                                                    |  "disappointment.",      |
# |                                                    |  "can't",                |
# |                                                    |  "thing",                |
# |                                                    |  "happended,",           |
# |                                                    |  "say,",                 |
# |                                                    |  "might've",             |
# |                                                    |  "drink",                |
# |                                                    |  "soda",                 |
# |                                                    |  "ice",                  |
# |                                                    |  "tea",                  |
# |                                                    |  "playing.",             |
# |                                                    |  "Hopefully",            |
# |                                                    |  "harp,",                |
# |                                                    |  "hohner",               |
# |                                                    |  "blue",                 |
# |                                                    |  "band,",                |
# |                                                    |  "play",                 |
# |                                                    |  "well",                 |
# |                                                    |  "last",                 |
# |                                                    |  "longer.",              |
# |                                                    |  "way,",                 |
# |                                                    |  "Great",                |
# |                                                    |  "price",                |
# |                                                    |  "good",                 |
# |                                                    |  "value.",               |
# |                                                    |  "hohner",               |
# |                                                    |  "raise",                |
# |                                                    |  "price",                |
# |                                                    |  "all,",                 |
# |                                                    |  "worth",                |
# |                                                    |  "it.",                  |
# |                                                    |  "Great",                |
# |                                                    |  "way",                  |
# |                                                    |  "pass",                 |
# |                                                    |  "time,",                |
# |                                                    |  "everywhere."           |
# |                                                    |]                         |
# |This works very well. It took some time for me ...  |[                         |
# |                                                    |  "work",                 |
# |                                                    |  "well.",                |
# |                                                    |  "take",                 |
# |                                                    |  "time",                 |
# |                                                    |  "figure",               |
# |                                                    |  "out.",                 |
# |                                                    |  "fit",                  |
# |                                                    |  "bill"                  |
# |                                                    |]                         |
# |Great story and well acted.  Can not wait for s...  |[                         |
# |                                                    |  "Great",                |
# |                                                    |  "story",                |
# |                                                    |  "acted.",               |
# |                                                    |  " ",                    |
# |                                                    |  "wait",                 |
# |                                                    |  "season",               |
# |                                                    |  "2."                    |
# |                                                    |]                         |
# |Interesting for what it is.                         |[                         |
# |                                                    |  "Interesting",          |
# |                                                    |  "is."                   |
# |                                                    |]                         |
# |Hae wanted this collection for a long timew.  T...  |[                         |
# |                                                    |  "Hae",                  |
# |                                                    |  "want",                 |
# |                                                    |  "collection",           |
# |                                                    |  "long",                 |
# |                                                    |  "timew.",               |
# |                                                    |  " ",                    |
# |                                                    |  "price",                |
# |                                                    |  "good.",                |
# |                                                    |  " ",                    |
# |                                                    |  "add",                  |
# |                                                    |  "lot",                  |
# |                                                    |  "collection."           |
# |                                                    |]                         |
# |Very nice quality and very comfortable.  I am s...  |[                         |
# |                                                    |  "nice",                 |
# |                                                    |  "quality",              |
# |                                                    |  "comfortable.",         |
# |                                                    |  " ",                    |
# |                                                    |  "shock",                |
# |                                                    |  "pay",                  |
# |                                                    |  "$37.",                 |
# |                                                    |  " ",                    |
# |                                                    |  "Great",                |
# |                                                    |  "deal,",                |
# |                                                    |  "don't",                |
# |                                                    |  "hesitate",             |
# |                                                    |  "buy",                  |
# |                                                    |  "it."                   |
# |                                                    |]                         |
# |You've got to watch this movie if you never hav...  |[                         |
# |                                                    |  "You've",               |
# |                                                    |  "get",                  |
# |                                                    |  "watch",                |
# |                                                    |  "movie",                |
# |                                                    |  "have.",                |
# |                                                    |  "Great",                |
# |                                                    |  "story,",               |
# |                                                    |  "superb",               |
# |                                                    |  "act",                  |
# |                                                    |  "lackluster",           |
# |                                                    |  "set",                  |
# |                                                    |  "design",               |
# |                                                    |  "costumes.",            |
# |                                                    |  "little",               |
# |                                                    |  "suspense",             |
# |                                                    |  "little",               |
# |                                                    |  "murder.",              |
# |                                                    |  "Good,",                |
# |                                                    |  "good",                 |
# |                                                    |  "film."                 |
# |                                                    |]                         |
# |A film about the impossible relations between a...  |[                         |
# |                                                    |  "film",                 |
# |Dr Jacques COULARDEAU                               |  "impossible",           |
# |                                                    |  "relation",             |
# |                                                    |  "father",               |
# |                                                    |  "son,",                 |
# |                                                    |  "2",                    |
# |                                                    |  "young",                |
# |                                                    |  "son",                  |
# |                                                    |  "background.",          |
# |                                                    |  "father",               |
# |                                                    |  "alcoholic.",           |
# |                                                    |  "violent",              |
# |                                                    |  "brutal.",              |
# |                                                    |  "educate",              |
# |                                                    |  "sons,",                |
# |                                                    |  "influence,",           |
# |                                                    |  "tyrannical",           |
# |                                                    |  "hand",                 |
# |                                                    |  "manage",               |
# |                                                    |  "state.",               |
# |                                                    |  "terrorize",            |
# |                                                    |  "wife",                 |
# |                                                    |  "block",                |
# |                                                    |  "son",                  |
# |                                                    |  "defensive",            |
# |                                                    |  "attitudes.",           |
# |                                                    |  "old",                  |
# |                                                    |  "son",                  |
# |                                                    |  "turn",                 |
# |                                                    |  "aggressive",           |
# |                                                    |  "paranoid.",            |
# |                                                    |  "young",                |
# |                                                    |  "son",                  |
# |                                                    |  "remain",               |
# |                                                    |  "aloof",                |
# |                                                    |  "protect",              |
# |                                                    |  "sanity",               |
# |                                                    |  "distance.",            |
# |                                                    |  "mother",               |
# |                                                    |  "suffer",               |
# |                                                    |  "eventually",           |
# |                                                    |  "die.",                 |
# |                                                    |  "old",                  |
# |                                                    |  "son",                  |
# |                                                    |  "reproduce",            |
# |                                                    |  "father's",             |
# |                                                    |  "domineer",             |
# |                                                    |  "attitude",             |
# |                                                    |  "wife",                 |
# |                                                    |  "daughter",             |
# |                                                    |  "get",                  |
# |                                                    |  "divorce",              |
# |                                                    |  "negociates",           |
# |                                                    |  "wrongly,",             |
# |                                                    |  "accept",               |
# |                                                    |  "wife",                 |
# |                                                    |  "appear",               |
# |                                                    |  "like",                 |
# |                                                    |  "father,",              |
# |                                                    |  "appear",               |
# |                                                    |  "like",                 |
# |                                                    |  "good",                 |
# |                                                    |  "father.",              |
# |                                                    |  "lead",                 |
# |                                                    |  "impossible",           |
# |                                                    |  "relation",             |
# |                                                    |  "daughter",             |
# |                                                    |  "react",                |
# |                                                    |  "defensively",          |
# |                                                    |  "once,",                |
# |                                                    |  "keep",                 |
# |                                                    |  "distance",             |
# |                                                    |  "father",               |
# |                                                    |  "probably",             |
# |                                                    |  "loves,",               |
# |                                                    |  "need",                 |
# |                                                    |  "him,",                 |
# |                                                    |  "hate",                 |
# |                                                    |  "communicate",          |
# |                                                    |  "him.",                 |
# |                                                    |  "try",                  |
# |                                                    |  "good",                 |
# |                                                    |  "impose",               |
# |                                                    |  "harshly",              |
# |                                                    |  "time",                 |
# |                                                    |  "treat",                |
# |                                                    |  "restaurant",           |
# |                                                    |  "ordeal.",              |
# |                                                    |  "care",                 |
# |                                                    |  "widowed",              |
# |                                                    |  "father",               |
# |                                                    |  "make",                 |
# |                                                    |  "jump",                 |
# |                                                    |  "edge",                 |
# |                                                    |  "abyss.",               |
# |                                                    |  "hunt",                 |
# |                                                    |  "accident",             |
# |                                                    |  "core",                 |
# |                                                    |  "plot",                 |
# |                                                    |  "teh",                  |
# |                                                    |  "community,",           |
# |                                                    |  "Jesus",                |
# |                                                    |  "Christ",               |
# |                                                    |  "justice",              |
# |                                                    |  "maker",                |
# |                                                    |  "village.",             |
# |                                                    |  "see",                  |
# |                                                    |  "speculation",          |
# |                                                    |  "miss",                 |
# |                                                    |  "point,",               |
# |                                                    |  "development",          |
# |                                                    |  "ski",                  |
# |                                                    |  "resort",               |
# |                                                    |  "village,",             |
# |                                                    |  "promote",              |
# |                                                    |  "rich",                 |
# |                                                    |  "community.",           |
# |                                                    |  "want",                 |
# |                                                    |  "change",               |
# |                                                    |  ":",                    |
# |                                                    |  "want",                 |
# |                                                    |  "explosive",            |
# |                                                    |  "self",                 |
# |                                                    |  "environment",          |
# |                                                    |  "produce",              |
# |                                                    |  "explosive",            |
# |                                                    |  "nature",               |
# |                                                    |  "his,",                 |
# |                                                    |  "morbid.",              |
# |                                                    |  "lead",                 |
# |                                                    |  "justice",              |
# |                                                    |  "trip,",                |
# |                                                    |  "kill",                 |
# |                                                    |  "cause",                |
# |                                                    |  "paranoia,",            |
# |                                                    |  "kill",                 |
# |                                                    |  "presume",              |
# |                                                    |  "assassin",             |
# |                                                    |  "assassin",             |
# |                                                    |  "all,",                 |
# |                                                    |  "disappear",            |
# |                                                    |  "limbo",                |
# |                                                    |  "anonimity",            |
# |                                                    |  "death",                |
# |                                                    |  "conscience.",          |
# |                                                    |  "film",                 |
# |                                                    |  "masterpiece",          |
# |                                                    |  "tell",                 |
# |                                                    |  "point",                |
# |                                                    |  "view",                 |
# |                                                    |  "young",                |
# |                                                    |  "son,",                 |
# |                                                    |  "point",                |
# |                                                    |  "view",                 |
# |                                                    |  "old",                  |
# |                                                    |  "son,",                 |
# |                                                    |  "mean",                 |
# |                                                    |  "limbo",                |
# |                                                    |  "society",              |
# |                                                    |  "finally",              |
# |                                                    |  "recover",              |
# |                                                    |  "distanciation",        |
# |                                                    |  "produce",              |
# |                                                    |  "perspective,",         |
# |                                                    |  "vista",                |
# |                                                    |  "life.",                |
# |                                                    |  "word",                 |
# |                                                    |  "thriller",             |
# |                                                    |  "come",                 |
# |                                                    |  "human",                |
# |                                                    |  "tragedy.",             |
# |                                                    |  "\n\n",                 |
# |                                                    |  "Dr",                   |
# |                                                    |  "Jacques",              |
# |                                                    |  "COULARDEAU"            |
# |                                                    |]                         |
# ---------------------------------------------------------------------------------

# %% [markdown]
# ### (Scaling) Snowpark Python Stored Procedure

# %% [markdown]
# #### Create Python Function to Transform the Data

# %%
def process_amazon_reviews(session: Session) -> Variant:
  # Load Movies and TV Reviews (8,765,580 records)
  df_amazon_reviews_movies = session.table('amazon_reviews_movies')

  # Load Musical Instruments Reviews (1,512,530 records)
  df_amazon_reviews_musical_inst = session.table('amazon_reviews_musical_instruments')

  # Combine Movies & TV with Musical Instruments Reviews (10,003,402 records)
  df_amazon_reviews_all = df_amazon_reviews_musical_inst.union(df_amazon_reviews_movies)

  # Replace Missing Values for REVIEWTEXT column with "Not available" (8,688 records)
  df_amazon_reviews_all = df_amazon_reviews_all.fillna('Not available',subset=["REVIEWTEXT"])

  # Call NLP UDF on column "REVIEWTEXT" to tokenize Amazon Reviews (10,003,402 records)
  df_amazon_reviews_all = df_amazon_reviews_all.select('*',call_udf('batch_nlp_tokenize_text',col('REVIEWTEXT')).as_("TOKENS"))

  # Save all columns including tokens in a new table (10,003,402 records)
  df_amazon_reviews_all.write.mode('overwrite').save_as_table('AMAZON_REVIEWS_WITH_TOKENS')

  return {"Status":"Success","Rows processed":df_amazon_reviews_all.count()}

# %% [markdown]
# #### Register Python Function as Snowpark Stored Procedure to Deploy Code to Snowflake

# %%
# Register function as a Stored Procedure
session.sproc.register(
  func=process_amazon_reviews,
  name="process_amazon_reviews",
  packages=['snowflake-snowpark-python'],
  is_permanent=True,
  stage_location="@dash_sprocs",
  replace=True)

# %% [markdown]
# #### Execute Snowpark Stored Procedure to Transform Data on Snowflake

# %%
print(session.call('process_amazon_reviews'))
# Out:
# {
#   "Rows processed": 10003402,
#   "Status": "Success"
# }

# %% [markdown]
# #### Examine Results - Reviews and Tokens

# %%
df_amazon_reviews_all = session.table('AMAZON_REVIEWS_WITH_TOKENS').select('REVIEWTEXT','TOKENS')
df_amazon_reviews_all.show()
# Out:
# -------------------------------------------------------------------------------
# |"REVIEWTEXT"                                        |"TOKENS"                |
# -------------------------------------------------------------------------------
# |In 1918, Mary Pickford was still "America's Swe...  |[                       |
# |                                                    |  "1918,",              |
# |"Amarilly of Clothes-Line Alley" revolves aroun...  |  "Mary",               |
# |                                                    |  "Pickford",           |
# |Amarilly is a street smart young woman who is d...  |  "\"America's",        |
# |                                                    |  "Sweetheart\"",       |
# |The two are happily in love but when a fire bre...  |  "popular",            |
# |                                                    |  "actress",            |
# |On the first night at the job, Amarilly meets t...  |  "big",                |
# |                                                    |  "screen.",            |
# |Meanwhile, the biggest snitch of Clothes-Line A...  |  " ",                  |
# |                                                    |  "1909,",              |
# |With chaos taking place at the club, a beaten u...  |  "actress",            |
# |                                                    |  "know",               |
# |Grateful for the help that Amarilly and her mot...  |  "dedication",         |
# |                                                    |  "work",               |
# |Meanwhile, Mrs. Phillips and her female members...  |  "decade",             |
# |                                                    |  "later,",             |
# |Will Amarilly last at the Phillips home?  Can s...  |  "time",               |
# |                                                    |  "begin",              |
# |For the 10-minute short "The Dream" which is in...  |  "work",               |
# |                                                    |  "\"Amarilly",         |
# |But then we see a transformation of Mary Pickfo...  |  "Clothes-Line",       |
# |                                                    |  "Alley\"",            |
# |The husband has realized that had mistreated hi...  |  "220",                |
# |                                                    |  "film",               |
# |VIDEO:                                              |  "belt.",              |
# |                                                    |  "\n\n",               |
# |"Amarilly of Clothes-Line Alley - The Milestone...  |  "\"Amarilly",         |
# |                                                    |  "Clothes-Line",       |
# |Quality-wise, "Amarilly of Clothes-Line Alley" ...  |  "Alley\"",            |
# |                                                    |  "revolve",            |
# |Surprisingly, the much older 1911 short film "T...  |  "Pickford's",         |
# |                                                    |  "character",          |
# |AUDIO & INTERTITLES:                                |  "Amarilly",           |
# |                                                    |  "Jenkins,",           |
# |"Amarilly of Clothes-Line Alley - The Milestone...  |  "eldest",             |
# |                                                    |  "daughter",           |
# |The Intertitles for "Amarilly of Clothes-Line A...  |  "Irish",              |
# |                                                    |  "family",             |
# |SPECIAL FEATURES:                                   |  "live",               |
# |                                                    |  "lower-class",        |
# |"Amarilly of Clothes-Line Alley - The Milestone...  |  "Clothes-Line",       |
# |                                                    |  "Alley",              |
# |JUDGMENT CALL:                                      |  "mother",             |
# |                                                    |  "(played",            |
# |As a silent film fan and having a good amount o...  |  "Kate",               |
# |                                                    |  "Price)",             |
# |But one thing people can count on is quality re...  |  "raise",              |
# |                                                    |  "brother",            |
# |But when it comes to Mary Pickford films, I fou...  |  "try",                |
# |                                                    |  "end",                |
# |There are some parts of the plot that probably ...  |  "meet",               |
# |                                                    |  "laundry",            |
# |But if anything, the melodramatic film shows he...  |  "business.",          |
# |                                                    |  "\n\n",               |
# |But I also found the IMP short "The Dream" to b...  |  "Amarilly",           |
# |                                                    |  "street",             |
# |But as simple as the short film was, what makes...  |  "smart",              |
# |                                                    |  "young",              |
# |Overall, "Amarilly of Clothes-Line Alley - The ...  |  "woman",              |
# |                                                    |  "date",               |
# |                                                    |  "Terry",              |
# |                                                    |  "McGowen",            |
# |                                                    |  "(played",            |
# |                                                    |  "William",            |
# |                                                    |  "Scott)",             |
# |                                                    |  "date",               |
# |                                                    |  "years.",             |
# |                                                    |  " ",                  |
# |                                                    |  "years,",             |
# |                                                    |  "kiss",               |
# |                                                    |  "Terry",              |
# |                                                    |  "wait",               |
# |                                                    |  "day",                |
# |                                                    |  "beloved",            |
# |                                                    |  "finally",            |
# |                                                    |  "kiss",               |
# |                                                    |  "him.",               |
# |                                                    |  "\n\n",               |
# |                                                    |  "happily",            |
# |                                                    |  "love",               |
# |                                                    |  "fire",               |
# |                                                    |  "break",              |
# |                                                    |  "Amarilly's",         |
# |                                                    |  "job,",               |
# |                                                    |  "blame",              |
# |                                                    |  "fire",               |
# |                                                    |  "fire",               |
# |                                                    |  "immediately",        |
# |                                                    |  "job.",               |
# |                                                    |  " ",                  |
# |                                                    |  "jobless,",           |
# |                                                    |  "Amarilly",           |
# |                                                    |  "worry",              |
# |                                                    |  "family",             |
# |                                                    |  "income",             |
# |                                                    |  "fortunately",        |
# |                                                    |  "boyfriend",          |
# |                                                    |  "Terry",              |
# |                                                    |  "come",               |
# |                                                    |  "rescue",             |
# |                                                    |  "get",                |
# |                                                    |  "job",                |
# |                                                    |  "sell",               |
# |                                                    |  "cigarette",          |
# |                                                    |  "local",              |
# |                                                    |  "club.",              |
# |                                                    |  "\n\n",               |
# |                                                    |  "night",              |
# |                                                    |  "job,",               |
# |                                                    |  "Amarilly",           |
# |                                                    |  "meet",               |
# |                                                    |  "dash",               |
# |                                                    |  "rich",               |
# |                                                    |  "Gordon",             |
# |                                                    |  "Phillips",           |
# |                                                    |  "(played",            |
# |                                                    |  "Norman",             |
# |                                                    |  "Kerry),",            |
# |                                                    |  "son",                |
# |                                                    |  "well-respected",     |
# |                                                    |  "Mrs.",               |
# |                                                    |  "David",              |
# |                                                    |  "Phillips",           |
# |                                                    |  "(played",            |
# |                                                    |  "Ida",                |
# |                                                    |  "Waterman).",         |
# |                                                    |  " ",                  |
# |                                                    |  "Terry",              |
# |                                                    |  "bite",               |
# |                                                    |  "jealous",            |
# |                                                    |  "rich",               |
# |                                                    |  "Gordon",             |
# |                                                    |  "talk",               |
# |                                                    |  "girlfriend",         |
# |                                                    |  "try",                |
# |                                                    |  "cool",               |
# |                                                    |  "it.",                |
# |                                                    |  "\n\n",               |
# |                                                    |  "Meanwhile,",         |
# |                                                    |  "big",                |
# |                                                    |  "snitch",             |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley,",             |
# |                                                    |  "\"Snitch\"",         |
# |                                                    |  "McCarthy",           |
# |                                                    |  "(played",            |
# |                                                    |  "Tom",                |
# |                                                    |  "Wilson)",            |
# |                                                    |  " ",                  |
# |                                                    |  "look",               |
# |                                                    |  "cause",              |
# |                                                    |  "trouble",            |
# |                                                    |  "tell",               |
# |                                                    |  "group",              |
# |                                                    |  "guy",                |
# |                                                    |  "Gordon",             |
# |                                                    |  "friend",             |
# |                                                    |  "try",                |
# |                                                    |  "pickup",             |
# |                                                    |  "woman",              |
# |                                                    |  "fight",              |
# |                                                    |  "break",              |
# |                                                    |  "club.",              |
# |                                                    |  "\n\n",               |
# |                                                    |  "chaos",              |
# |                                                    |  "take",               |
# |                                                    |  "place",              |
# |                                                    |  "club,",              |
# |                                                    |  "beat",               |
# |                                                    |  "Gordon",             |
# |                                                    |  "stumble",            |
# |                                                    |  "club",               |
# |                                                    |  "Amarilly",           |
# |                                                    |  "go",                 |
# |                                                    |  "help",               |
# |                                                    |  "him.",               |
# |                                                    |  " ",                  |
# |                                                    |  "take",               |
# |                                                    |  "home",               |
# |                                                    |  "mother",             |
# |                                                    |  "help",               |
# |                                                    |  "heal",               |
# |                                                    |  "right",              |
# |                                                    |  "watch",              |
# |                                                    |  "\"Snitch\"",         |
# |                                                    |  "McCarthy",           |
# |                                                    |  "begin",              |
# |                                                    |  "tell",               |
# |                                                    |  "people",             |
# |                                                    |  "Amarilly",           |
# |                                                    |  "cozied",             |
# |                                                    |  "rich",               |
# |                                                    |  "Gordon",             |
# |                                                    |  "Phillips.",          |
# |                                                    |  " ",                  |
# |                                                    |  "thing",              |
# |                                                    |  "worse,",             |
# |                                                    |  "Terry",              |
# |                                                    |  "go",                 |
# |                                                    |  "visit",              |
# |                                                    |  "Amarilly",           |
# |                                                    |  "find",               |
# |                                                    |  "Gordon",             |
# |                                                    |  "place",              |
# |                                                    |  "take",               |
# |                                                    |  "care",               |
# |                                                    |  "Amarilly's",         |
# |                                                    |  "mother",             |
# |                                                    |  "think",              |
# |                                                    |  "maybe",              |
# |                                                    |  "together.",          |
# |                                                    |  " ",                  |
# |                                                    |  "Terry,",             |
# |                                                    |  "jealous,",           |
# |                                                    |  "bolt",               |
# |                                                    |  "leaves.",            |
# |                                                    |  "\n\n",               |
# |                                                    |  "Grateful",           |
# |                                                    |  "help",               |
# |                                                    |  "Amarilly",           |
# |                                                    |  "mother",             |
# |                                                    |  "him,",               |
# |                                                    |  "offer",              |
# |                                                    |  "Amarilly",           |
# |                                                    |  "job",                |
# |                                                    |  "clean",              |
# |                                                    |  "art",                |
# |                                                    |  "studio",             |
# |                                                    |  "mother",             |
# |                                                    |  "laundry",            |
# |                                                    |  "needless",           |
# |                                                    |  "say,",               |
# |                                                    |  "Amarilly",           |
# |                                                    |  "mother",             |
# |                                                    |  "grateful.",          |
# |                                                    |  " ",                  |
# |                                                    |  "grateful",           |
# |                                                    |  "boyfriend",          |
# |                                                    |  "Terry",              |
# |                                                    |  "hear",               |
# |                                                    |  "rumor",              |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley",              |
# |                                                    |  "Amarilly",           |
# |                                                    |  "Gordon.",            |
# |                                                    |  " ",                  |
# |                                                    |  "Jealous",            |
# |                                                    |  "confuse",            |
# |                                                    |  "let",                |
# |                                                    |  "Amarilly",           |
# |                                                    |  "explanation",        |
# |                                                    |  "Gordon",             |
# |                                                    |  "place,",             |
# |                                                    |  "break",              |
# |                                                    |  "her.",               |
# |                                                    |  "\n\n",               |
# |                                                    |  "Meanwhile,",         |
# |                                                    |  "Mrs.",               |
# |                                                    |  "Phillips",           |
# |                                                    |  "female",             |
# |                                                    |  "member",             |
# |                                                    |  "\"The",              |
# |                                                    |  "Society",            |
# |                                                    |  "Betterment",         |
# |                                                    |  "Humanity\"",         |
# |                                                    |  "meet",               |
# |                                                    |  "want",               |
# |                                                    |  "work",               |
# |                                                    |  "experiment.",        |
# |                                                    |  " ",                  |
# |                                                    |  "young",              |
# |                                                    |  "poor",               |
# |                                                    |  "try",                |
# |                                                    |  "debutante.",         |
# |                                                    |  " ",                  |
# |                                                    |  "Scarlet",            |
# |                                                    |  "Fever",              |
# |                                                    |  "break",              |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley",              |
# |                                                    |  "area",               |
# |                                                    |  "quarantined,",       |
# |                                                    |  "Gordon",             |
# |                                                    |  "offer",              |
# |                                                    |  "stay",               |
# |                                                    |  "mother's",           |
# |                                                    |  "place",              |
# |                                                    |  "immediately",        |
# |                                                    |  "Mrs.",               |
# |                                                    |  "Phillips",           |
# |                                                    |  "woman",              |
# |                                                    |  "choose",             |
# |                                                    |  "Amarilly",           |
# |                                                    |  "test",               |
# |                                                    |  "example.",           |
# |                                                    |  "\n\n",               |
# |                                                    |  "Amarilly",           |
# |                                                    |  "Phillips",           |
# |                                                    |  "home?",              |
# |                                                    |  " ",                  |
# |                                                    |  "debutante?",         |
# |                                                    |  " ",                  |
# |                                                    |  "ex-boyfriend",       |
# |                                                    |  "Terry?",             |
# |                                                    |  " ",                  |
# |                                                    |  "come",               |
# |                                                    |  "senses?",            |
# |                                                    |  "\n\n",               |
# |                                                    |  "10-minute",          |
# |                                                    |  "short",              |
# |                                                    |  "\"The",              |
# |                                                    |  "Dream\"",            |
# |                                                    |  "include",            |
# |                                                    |  "special",            |
# |                                                    |  "feature,",           |
# |                                                    |  "Mary",               |
# |                                                    |  "Pickford",           |
# |                                                    |  "play",               |
# |                                                    |  "love",               |
# |                                                    |  "wife",               |
# |                                                    |  "husband",            |
# |                                                    |  "have",               |
# |                                                    |  "affair",             |
# |                                                    |  "thing",              |
# |                                                    |  "he's",               |
# |                                                    |  "gone.",              |
# |                                                    |  " ",                  |
# |                                                    |  "Mary's",             |
# |                                                    |  "character",          |
# |                                                    |  "cook",               |
# |                                                    |  "man",                |
# |                                                    |  "come",               |
# |                                                    |  "home",               |
# |                                                    |  "difficult",          |
# |                                                    |  "mean",               |
# |                                                    |  "wife,",              |
# |                                                    |  "throw",              |
# |                                                    |  "chair",              |
# |                                                    |  "treat",              |
# |                                                    |  "wrong.",             |
# |                                                    |  "\n\n",               |
# |                                                    |  "transformation",     |
# |                                                    |  "Mary",               |
# |                                                    |  "Pickford's",         |
# |                                                    |  "character,",         |
# |                                                    |  "love",               |
# |                                                    |  "wife",               |
# |                                                    |  "trash-talking,",     |
# |                                                    |  "smoke",              |
# |                                                    |  "rude",               |
# |                                                    |  "crude",              |
# |                                                    |  "woman",              |
# |                                                    |  "destroy",            |
# |                                                    |  "home",               |
# |                                                    |  "laugh",              |
# |                                                    |  "husband's",          |
# |                                                    |  "face",               |
# |                                                    |  "leave",              |
# |                                                    |  "rich",               |
# |                                                    |  "man.",               |
# |                                                    |  "\n\n",               |
# |                                                    |  "husband",            |
# |                                                    |  "realize",            |
# |                                                    |  "mistreat",           |
# |                                                    |  "wife,",              |
# |                                                    |  "husband",            |
# |                                                    |  "want",               |
# |                                                    |  "back.",              |
# |                                                    |  "\n\n",               |
# |                                                    |  "VIDEO:",             |
# |                                                    |  "\n\n",               |
# |                                                    |  "\"Amarilly",         |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley",              |
# |                                                    |  "-",                  |
# |                                                    |  "Milestone",          |
# |                                                    |  "Collection\"",       |
# |                                                    |  "present",            |
# |                                                    |  "4:3",                |
# |                                                    |  "present",            |
# |                                                    |  "B&W",                |
# |                                                    |  "color",              |
# |                                                    |  "tint",               |
# |                                                    |  "short",              |
# |                                                    |  "\"The",              |
# |                                                    |  "Dream\"",            |
# |                                                    |  "present",            |
# |                                                    |  "B&W.",               |
# |                                                    |  " ",                  |
# |                                                    |  "old",                |
# |                                                    |  "DVD",                |
# |                                                    |  "release,",           |
# |                                                    |  "DVD's",              |
# |                                                    |  "time",               |
# |                                                    |  "know",               |
# |                                                    |  "comb",               |
# |                                                    |  "case,",              |
# |                                                    |  "comb",               |
# |                                                    |  "watch",              |
# |                                                    |  "pause",              |
# |                                                    |  "small",              |
# |                                                    |  "monitor",            |
# |                                                    |  "computer.",          |
# |                                                    |  " ",                  |
# |                                                    |  "didn't",             |
# |                                                    |  "notice",             |
# |                                                    |  "comb",               |
# |                                                    |  "watch",              |
# |                                                    |  "large",              |
# |                                                    |  "television.",        |
# |                                                    |  "\n\n",               |
# |                                                    |  "Quality-wise,",      |
# |                                                    |  "\"Amarilly",         |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley\"",            |
# |                                                    |  "look",               |
# |                                                    |  "good",               |
# |                                                    |  "film",               |
# |                                                    |  "92-years-old.",      |
# |                                                    |  " ",                  |
# |                                                    |  "Granted,",           |
# |                                                    |  "sure",               |
# |                                                    |  "detail",             |
# |                                                    |  "evident",            |
# |                                                    |  "new",                |
# |                                                    |  "remaster",           |
# |                                                    |  "modern",             |
# |                                                    |  "DVD",                |
# |                                                    |  "technology",         |
# |                                                    |  "2010",               |
# |                                                    |  "vs.",                |
# |                                                    |  "restore",            |
# |                                                    |  "teh",                |
# |                                                    |  "film",               |
# |                                                    |  "2009",               |
# |                                                    |  "overall,",           |
# |                                                    |  "look",               |
# |                                                    |  "good",               |
# |                                                    |  "old",                |
# |                                                    |  "film.",              |
# |                                                    |  " ",                  |
# |                                                    |  "occasional",         |
# |                                                    |  "scratch",            |
# |                                                    |  "dust",               |
# |                                                    |  "hurt",               |
# |                                                    |  "film",               |
# |                                                    |  "prevent",            |
# |                                                    |  "enjoyment",          |
# |                                                    |  "it.",                |
# |                                                    |  "\n\n",               |
# |                                                    |  "Surprisingly,",      |
# |                                                    |  "old",                |
# |                                                    |  "1911",               |
# |                                                    |  "short",              |
# |                                                    |  "film",               |
# |                                                    |  "\"The",              |
# |                                                    |  "Dream\"",            |
# |                                                    |  "99-years-old",       |
# |                                                    |  "look",               |
# |                                                    |  "fantastic.",         |
# |                                                    |  " ",                  |
# |                                                    |  "Granted,",           |
# |                                                    |  "film",               |
# |                                                    |  "share",              |
# |                                                    |  "dust",               |
# |                                                    |  "scratch",            |
# |                                                    |  "black",              |
# |                                                    |  "nice",               |
# |                                                    |  "deep",               |
# |                                                    |  "contrast",           |
# |                                                    |  "good",               |
# |                                                    |  "film",               |
# |                                                    |  "old.",               |
# |                                                    |  " ",                  |
# |                                                    |  "happy",              |
# |                                                    |  "film",               |
# |                                                    |  "include",            |
# |                                                    |  "DVD.",               |
# |                                                    |  "\n\n",               |
# |                                                    |  "AUDIO",              |
# |                                                    |  "&",                  |
# |                                                    |  "INTERTITLES:",       |
# |                                                    |  "\n\n",               |
# |                                                    |  "\"Amarilly",         |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley",              |
# |                                                    |  "-",                  |
# |                                                    |  "Milestone",          |
# |                                                    |  "Collection\"",       |
# |                                                    |  "feature",            |
# |                                                    |  "chamber",            |
# |                                                    |  "score",              |
# |                                                    |  "Mont",               |
# |                                                    |  "Alto",               |
# |                                                    |  "Orchestra.",         |
# |                                                    |  " ",                  |
# |                                                    |  "chamber",            |
# |                                                    |  "score",              |
# |                                                    |  "work",               |
# |                                                    |  "film",               |
# |                                                    |  "piano",              |
# |                                                    |  "performance",        |
# |                                                    |  "Marco",              |
# |                                                    |  "Antonio",            |
# |                                                    |  "De",                 |
# |                                                    |  "Almeida",            |
# |                                                    |  "(based",             |
# |                                                    |  "music",              |
# |                                                    |  "Ernesto",            |
# |                                                    |  "Nazareth)",          |
# |                                                    |  "\"The",              |
# |                                                    |  "Dream\"",            |
# |                                                    |  "niceley",            |
# |                                                    |  "done.",              |
# |                                                    |  "\n\n",               |
# |                                                    |  "Intertitles",        |
# |                                                    |  "\"Amarilly",         |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley\"",            |
# |                                                    |  "easy",               |
# |                                                    |  "read,",              |
# |                                                    |  "\"The",              |
# |                                                    |  "Dream\"",            |
# |                                                    |  "intertitle",         |
# |                                                    |  "break",              |
# |                                                    |  "little",             |
# |                                                    |  "verbage",            |
# |                                                    |  "story",              |
# |                                                    |  "self-explanatory.",  |
# |                                                    |  "\n\n",               |
# |                                                    |  "SPECIAL",            |
# |                                                    |  "FEATURES:",          |
# |                                                    |  "\n\n",               |
# |                                                    |  "\"Amarilly",         |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley",              |
# |                                                    |  "-",                  |
# |                                                    |  "Milestone",          |
# |                                                    |  "Collection\"",       |
# |                                                    |  "come",               |
# |                                                    |  "1911",               |
# |                                                    |  "film",               |
# |                                                    |  "\"The",              |
# |                                                    |  "Dream\"",            |
# |                                                    |  "(restored",          |
# |                                                    |  "recently",           |
# |                                                    |  "find",               |
# |                                                    |  "1999).",             |
# |                                                    |  "\n\n",               |
# |                                                    |  "JUDGMENT",           |
# |                                                    |  "CALL:",              |
# |                                                    |  "\n\n",               |
# |                                                    |  "silent",             |
# |                                                    |  "film",               |
# |                                                    |  "fan",                |
# |                                                    |  "have",               |
# |                                                    |  "good",               |
# |                                                    |  "silent",             |
# |                                                    |  "film",               |
# |                                                    |  "collection,",        |
# |                                                    |  "I've",               |
# |                                                    |  "come",               |
# |                                                    |  "point",              |
# |                                                    |  "life",               |
# |                                                    |  "want",               |
# |                                                    |  "Mary",               |
# |                                                    |  "Pickford",           |
# |                                                    |  "film",               |
# |                                                    |  "unfortunately,",     |
# |                                                    |  "available",          |
# |                                                    |  "DVD",                |
# |                                                    |  "are,",               |
# |                                                    |  "company",            |
# |                                                    |  "terrible",           |
# |                                                    |  "job",                |
# |                                                    |  "reuse",              |
# |                                                    |  "music",              |
# |                                                    |  "music",              |
# |                                                    |  "doesn't",            |
# |                                                    |  "match",              |
# |                                                    |  "film.",              |
# |                                                    |  "\n\n",               |
# |                                                    |  "thing",              |
# |                                                    |  "people",             |
# |                                                    |  "count",              |
# |                                                    |  "quality",            |
# |                                                    |  "release",            |
# |                                                    |  "Milestone",          |
# |                                                    |  "Film",               |
# |                                                    |  "&",                  |
# |                                                    |  "Video",              |
# |                                                    |  "collaboration",      |
# |                                                    |  "Image",              |
# |                                                    |  "Entertainment,",     |
# |                                                    |  "dozen",              |
# ...
# |                                                    |  "crude",              |
# |                                                    |  "woman,",             |
# |                                                    |  "Pickford",           |
# |                                                    |  "charm",              |
# |                                                    |  "watch",              |
# |                                                    |  "film",               |
# |                                                    |  "wonderful",          |
# |                                                    |  "inclusion",          |
# |                                                    |  "DVD.",               |
# |                                                    |  "\n\n",               |
# |                                                    |  "Overall,",           |
# |                                                    |  "\"Amarilly",         |
# |                                                    |  "Clothes-Line",       |
# |                                                    |  "Alley",              |
# |                                                    |  "-",                  |
# |                                                    |  "Milestone",          |
# |                                                    |  "Collection\"",       |
# |                                                    |  "solid",              |
# |                                                    |  "release",            |
# |                                                    |  "Pickford",           |
# |                                                    |  "film.",              |
# |                                                    |  " ",                  |
# |                                                    |  "well",               |
# |                                                    |  "film",               |
# |                                                    |  "entertain",          |
# |                                                    |  "fact",               |
# |                                                    |  "1911",               |
# |                                                    |  "short",              |
# |                                                    |  "make",               |
# |                                                    |  "DVD",                |
# |                                                    |  "release",            |
# |                                                    |  "worth",              |
# |                                                    |  "it.",                |
# |                                                    |  " ",                  |
# |                                                    |  "consider",           |
# |                                                    |  "aren't",             |
# |                                                    |  "Mary",               |
# |                                                    |  "Pickford",           |
# |                                                    |  "film",               |
# |                                                    |  "available",          |
# |                                                    |  "DVD,",               |
# |                                                    |  "I'm",                |
# |                                                    |  "grateful",           |
# |                                                    |  "Milestone",          |
# |                                                    |  "Collection",         |
# |                                                    |  "release",            |
# |                                                    |  "DVD",                |
# |                                                    |  "hopefully",          |
# |                                                    |  "Pickford",           |
# |                                                    |  "release",            |
# |                                                    |  "near",               |
# |                                                    |  "future."             |
# |                                                    |]                       |
# |Lain is great.  All of it.  It's a bit dark, go...  |[                       |
# |                                                    |  "Lain",               |
# |                                                    |  "great.",             |
# |                                                    |  " ",                  |
# |                                                    |  "it.",                |
# |                                                    |  " ",                  |
# |                                                    |  "It's",               |
# |                                                    |  "bite",               |
# |                                                    |  "dark,",              |
# |                                                    |  "go",                 |
# |                                                    |  "anime",              |
# |                                                    |  "tropes,",            |
# |                                                    |  "isn't",              |
# |                                                    |  "terribly",           |
# |                                                    |  "energetic",          |
# |                                                    |  "it's",               |
# |                                                    |  "unique,",            |
# |                                                    |  "well-scored,",       |
# |                                                    |  "atmospheric.",       |
# |                                                    |  " ",                  |
# |                                                    |  "watch."              |
# |                                                    |]                       |
# |I saw this when it was released, and I was in h...  |[                       |
# |Can't believe it's only now available on Blu! I...  |  "see",                |
# |                                                    |  "released,",          |
# |                                                    |  "high",               |
# |                                                    |  "school...",          |
# |                                                    |  "remarkably",         |
# |                                                    |  "fine-grained",       |
# |                                                    |  "digital",            |
# |                                                    |  "transfer.",          |
# |                                                    |  "\n",                 |
# |                                                    |  "Can't",              |
# |                                                    |  "believe",            |
# |                                                    |  "it's",               |
# |                                                    |  "available",          |
# |                                                    |  "Blu!",               |
# |                                                    |  "you're",             |
# |                                                    |  "plan",               |
# |                                                    |  "Havana",             |
# |                                                    |  "vacation",           |
# |                                                    |  "now,",               |
# |                                                    |  "sure",               |
# |                                                    |  "first..."            |
# |                                                    |]                       |
# |Doesn't fit any where on the drum set. Doesn't ...  |[                       |
# |                                                    |  "Doesn't",            |
# |                                                    |  "fit",                |
# |                                                    |  "drum",               |
# |                                                    |  "set.",               |
# |                                                    |  "Doesn't",            |
# |                                                    |  "different",          |
# |                                                    |  "direction",          |
# |                                                    |  "like",               |
# |                                                    |  "think",              |
# |                                                    |  "suppose",            |
# |                                                    |  "to."                 |
# |                                                    |]                       |
# |Excellent quality for a great price. Perfect fo...  |[                       |
# |  Would recommend this based on price and tone ...  |  "Excellent",          |
# |                                                    |  "quality",            |
# |                                                    |  "great",              |
# |                                                    |  "price.",             |
# |                                                    |  "Perfect",            |
# |                                                    |  "middle",             |
# |                                                    |  "school",             |
# |                                                    |  "age",                |
# |                                                    |  "daughter",           |
# |                                                    |  "play",               |
# |                                                    |  "orchestra.",         |
# |                                                    |  "\n  ",               |
# |                                                    |  "recommend",          |
# |                                                    |  "base",               |
# |                                                    |  "price",              |
# |                                                    |  "tone",               |
# |                                                    |  "sound",              |
# |                                                    |  "quality."            |
# |                                                    |]                       |
# |Oh my gosh- thank you! Definitely helps the "ho...  |[                       |
# |                                                    |  "Oh",                 |
# |                                                    |  "gosh-",              |
# |                                                    |  "thank",              |
# |                                                    |  "you!",               |
# |                                                    |  "Definitely",         |
# |                                                    |  "help",               |
# |                                                    |  "\"household",        |
# |                                                    |  "noise\",",           |
# |                                                    |  "4",                  |
# |                                                    |  "kids,",              |
# |                                                    |  "violin",             |
# |                                                    |  "&",                  |
# |                                                    |  "add",                |
# |                                                    |  "trumpet-",           |
# |                                                    |  "eek!"                |
# |                                                    |]                       |
# |They were super brittle. Broke way too easily.      |[                       |
# |                                                    |  "super",              |
# |                                                    |  "brittle.",           |
# |                                                    |  "Broke",              |
# |                                                    |  "way",                |
# |                                                    |  "easily."             |
# |                                                    |]                       |
# |Well made product. Highly recommend.                |[                       |
# |                                                    |  "product.",           |
# |                                                    |  "Highly",             |
# |                                                    |  "recommend."          |
# |                                                    |]                       |
# |This mic does an amazing job and works great to...  |[                       |
# |                                                    |  "mic",                |
# |                                                    |  "amaze",              |
# |                                                    |  "job",                |
# |                                                    |  "work",               |
# |                                                    |  "great",              |
# |                                                    |  "capture",            |
# |                                                    |  "room",               |
# |                                                    |  "voice",              |
# |                                                    |  "instrument.",        |
# |                                                    |  "blow",               |
# |                                                    |  "away",               |
# |                                                    |  "quality",            |
# |                                                    |  "price",              |
# |                                                    |  "here."               |
# |                                                    |]                       |
# |The guitar has a nice sound, and it's pretty li...  |[                       |
# |The two things that I don't really like is that...  |  "guitar",             |
# |Still pretty happy about it.                        |  "nice",               |
# |                                                    |  "sound,",             |
# |                                                    |  "it's",               |
# |                                                    |  "pretty",             |
# |                                                    |  "light.",             |
# |                                                    |  "\n",                 |
# |                                                    |  "thing",              |
# |                                                    |  "don't",              |
# |                                                    |  "like",               |
# |                                                    |  "noise",              |
# |                                                    |  "plugged,",           |
# |                                                    |  "plug",               |
# |                                                    |  "go",                 |
# |                                                    |  "inside",             |
# |                                                    |  "guitar",             |
# |                                                    |  "reason.",            |
# |                                                    |  "\n",                 |
# |                                                    |  "pretty",             |
# |                                                    |  "happy",              |
# |                                                    |  "it."                 |
# |                                                    |]                       |
# -------------------------------------------------------------------------------
