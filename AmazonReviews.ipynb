# %% [markdown]
# # Amazon Reviews
#
# #### Overview:
#
# * Import Python Libraries
# * Estabish Secure Connetion to Snowflake using AWS Secrets Manager
# * Exploratory Data Analysis using Snowpark DataFrames
#   * Load data into Snowpark DataFrames
#     * Movies and TV reviews
#     * Musical Instruments Reviews
#   * Snowpark DataFrame Actions and Transformations
#     * Access Semi-structured Data using Snowpark DataFrame API
#     * Combine Movies & TV with Musical Instruments Reviews
#     * Replace Missing Values for REVIEWTEXT column with "Not available"
#   * Snowpark Python User-Defined Function (UDF)
#     * (Simple) Create and Register UDF named "to_lowercase"
#     * Call "to_lowercase" UDF on "SUMMARY" column in Snowpark DataFrame
#     * (Complex) Create and Register Natural Language Processing (NLP) UDF using spaCy and BeautifulSoup
#     * Call NLP UDF on column "REVIEWTEXT" in Snowpark DataFrame to tokenize Amazon Reviews
#   * Snowpark Python Stored Procedure (SP)
#     * Create Python Function to Transform Data
#     * Register Python Function as Snowpark Stored Procedure to Deploy Code to Snowflake
#     * Execute Snowpark Stored Procedure to Transform Data on Snowflake
#     * Examine Results - Reviews and Tokens
#
# *Data Source: https://cseweb.ucsd.edu/~jmcauley/datasets/amazon_v2/*

# %% [markdown]
# ### Import Python Libraries

# %%
# Snowpark
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import PandasSeries, PandasDataFrame
from snowflake.snowpark.functions import udf, count, avg, sum, col,lit,listagg,call_builtin,when,count_distinct,array_agg,array_construct,call_udf,sproc,parse_json,json_extract_path_text,get_path
from snowflake.snowpark.version import VERSION

# Misc
import pandas as pd
import json
from cachetools import cached
import logging 
logger = logging.getLogger("snowflake.snowpark.session")
logger.setLevel(logging.ERROR)

# For AWS Secrets Manager
import boto3
from botocore.exceptions import ClientError

# %% [markdown]
# ### Establish Secure Connection to Snowflake using AWS Secrets Manager
#
# *NOTE: Other options include loading credentials from a file (for example, connection.json), Okta, SSO, MFA*

# %%
# Load Snowflake connection details from AWS Secrets Manager
def get_aws_sf_connection_details(secret_name,region_name):
    
    # Create a Secrets Manager boto3 client
    boto3_session = boto3.session.Session()
    client = boto3_session.client(service_name='secretsmanager',region_name=region_name)
    
    get_secret_value_response = None

    try:
        # Get secret values(s) based on the passed in secret name
        get_secret_value_response = client.get_secret_value(SecretId=secret_name)['SecretString']
    except ClientError as e:
        if e.response['Error']['Code'] == 'DecryptionFailureException':
            # Secrets Manager can't decrypt the protected secret text using the provided KMS key.
            raise e
        elif e.response['Error']['Code'] == 'InternalServiceErrorException':
            # An error occurred on the server side.
            raise e
        elif e.response['Error']['Code'] == 'InvalidParameterException':
            # You provided an invalid value for a parameter.
            raise e
        elif e.response['Error']['Code'] == 'InvalidRequestException':
            # You provided a parameter value that is not valid for the current state of the resource.
            raise e
        elif e.response['Error']['Code'] == 'ResourceNotFoundException':
            # We can't find the resource that you asked for.
            raise e

    return get_secret_value_response
        
# Create Snowflake Session object
connection_parameters = json.loads(get_aws_sf_connection_details('dash-sfdevrel-connection','us-west-2'))
session = Session.builder.configs(connection_parameters).create()

snowflake_environment = session.sql('select current_role(), current_warehouse(), current_database(), current_schema(), current_version()').collect()
snowpark_version = VERSION

# Current Environment Details
print('Role                        : {}'.format(snowflake_environment[0][0]))
print('Warehouse                   : {}'.format(snowflake_environment[0][1]))
print('Database                    : {}'.format(snowflake_environment[0][2]))
print('Schema                      : {}'.format(snowflake_environment[0][3]))
print('Snowflake version           : {}'.format(snowflake_environment[0][4]))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
# Out:
# Role                        : ACCOUNTADMIN
# Warehouse                   : DASH_S
# Database                    : DASH_DB
# Schema                      : DASH_SCHEMA
# Snowflake version           : 7.9.0
# Snowpark for Python version : 1.0.0

# %% [markdown]
# ### Exploratory Data Analysis using Snowpark DataFrames
#
# #### Load data into Snowpark DataFrames

# %% [markdown]
# ##### Movies & TV Reviews

# %%
df_amazon_reviews_movies = session.table('amazon_reviews_movies')
df_amazon_reviews_movies.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"OVERALL"  |"VERIFIED"  |"REVIEWTIME"  |"REVIEWERID"    |"ASIN"      |"STYLE"                |"REVIEWERNAME"  |"REVIEWTEXT"                                        |"SUMMARY"                                           |"UNIXREVIEWTIME"  |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |5          |True        |07 12, 2010   |A32O1V2PKOE5DY  |B000UR9TKK  |"{'Format:': ' DVD'}"  |Morryt          |I love my collection of the nine seasons of Eve...  |My therape is here!                                 |1278892800        |
# |5          |False       |07 5, 2010    |A16GAIJJE39T1S  |B000UR9TKK  |"{'Format:': ' DVD'}"  |Ulfilas         |Anybody who is married and aware of the complex...  |Uncanny in its evocation of family life--and Pa...  |1278288000        |
# |           |            |              |                |            |                       |                |                                                    |                                                    |                  |
# |           |            |              |                |            |                       |                |This show has a really talented cast!  That sai...  |                                                    |                  |
# |           |            |              |                |            |                       |                |                                                    |                                                    |                  |
# |           |            |              |                |            |                       |                |My private wish is for Patricia Heaton to play ...  |                                                    |                  |
# |5          |True        |06 30, 2010   |A3OB3WDUN51D8A  |B000UR9TKK  |"{'Format:': ' DVD'}"  |Sterling        |Well-written, very funny, honest portrayal of l...  |Great show                                          |1277856000        |
# |           |            |              |                |            |                       |                |As in the past, Amazon gets five enthusiastic s...  |                                                    |                  |
# |5          |True        |06 28, 2010   |AK0YHMFZL3COF   |B000UR9TKK  |"{'Format:': ' DVD'}"  |sddeal          |What a fantastic deal on the entire Everybody L...  |What a deal!                                        |1277683200        |
# |5          |True        |06 27, 2010   |A3EG3DLQ6SGHJI  |B000UR9TKK  |"{'Format:': ' DVD'}"  |Ann Comer       |I don't know where I was or what I was doing wh...  |I just love "Everyone Loves Raymond"                |1277596800        |
# |4          |True        |06 27, 2010   |A3SPIHCWS2XS07  |B000UR9TKK  |"{'Format:': ' DVD'}"  |Matt            |This is a great set of DVD's with all the episo...  |Everybody Loves Raymond                             |1277596800        |
# |1          |True        |06 26, 2010   |AMQ499GPAFKD9   |B000UR9TKK  |"{'Format:': ' DVD'}"  |Mom6            |I never received this item and the seller never...  |movie review                                        |1277510400        |
# |2          |True        |06 26, 2010   |A7CCQDBZVAHZV   |B000UR9TKK  |"{'Format:': ' DVD'}"  |Truth Seeker    |The good:  This show is great!  I could recomme...  |5 Stars for show - 1 Star for Amazon and their ...  |1277510400        |
# |           |            |              |                |            |                       |                |                                                    |                                                    |                  |
# |           |            |              |                |            |                       |                |The bad:  The first shipment I got from Amazon ...  |                                                    |                  |
# |           |            |              |                |            |                       |                |                                                    |                                                    |                  |
# |           |            |              |                |            |                       |                |The ugly:  Amazon won't send a replacement for ...  |                                                    |                  |
# |4          |True        |06 26, 2010   |A32GIKLGNNYXAQ  |B000UR9TKK  |"{'Format:': ' DVD'}"  |R. Bellerose    |Love the series and price is awesome,only compl...  |Great Deal                                          |1277510400        |
# |5          |True        |05 31, 2010   |ASLXTGSDF4HW3   |B000UR9TKK  |"{'Format:': ' DVD'}"  |TC              |I have always wanted this set I love Everbody L...  |Everybody loves Raymond complete series             |1275264000        |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Musical Instruments Reviews

# %%
df_amazon_reviews_musical_inst = session.table('amazon_reviews_musical_instruments')
df_amazon_reviews_musical_inst.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"OVERALL"  |"VERIFIED"  |"REVIEWTIME"  |"REVIEWERID"    |"ASIN"      |"STYLE"  |"REVIEWERNAME"       |"REVIEWTEXT"                                        |"SUMMARY"                                           |"UNIXREVIEWTIME"  |
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |5          |true        |07 7, 2018    |A5NUSGGKE1BNB   |B01H7N27L2  |NULL     |Mason                |Perfect fit and comfortable. Nice pocket placem...  |Great saddle, just what i needed                    |1530921600        |
# |5          |true        |03 15, 2018   |A3ELFQ6XR2RBPH  |B01H7N27L2  |NULL     |Brian C. Hagerty     |This is a very comfortable seat and provides ni...  |Sturdy, comfortable, and convenient. A very nic...  |1521072000        |
# |2          |true        |02 9, 2018    |A1WW6RC4PTVNGA  |B01H7N27L2  |NULL     |David L.             |Overpriced for what it is.  It comes with nothi...  |Overpriced for what it is. It comes with nothin...  |1518134400        |
# |4          |true        |12 5, 2017    |ARNSI65BQSM5    |B01H7N27L2  |NULL     |Kevin                |Its good, but the cushion doesnt actually provi...  |Its good, but the cushion doesnt actually provi...  |1512432000        |
# |4          |true        |08 6, 2017    |A20FKK2S0ENBW1  |B01H7N27L2  |NULL     |Matt Ehrenzeller     |Your butt will thank you. It does muffle the so...  |Four Stars                                          |1501977600        |
# |5          |true        |05 26, 2017   |A11ULYDX46WOXB  |B01H7N27L2  |NULL     |Nilo Moriconi        |good                                                |Five Stars                                          |1495756800        |
# |5          |true        |04 8, 2017    |A8MVQVBE3P0K5   |B01H7N27L2  |NULL     |Matthew J Harradine  |Love it. I have a cabasa velcroed to one side a...  |Love it. I have a cabasa velcroed to one ...        |1491609600        |
# |4          |false       |01 24, 2017   |ATKT6ZO4JT7BX   |B01H7N27L2  |NULL     |jgscroggins          |The saddle is a much needed accessory to the wo...  |Great accessory; needs firmer padding...            |1485216000        |
# |           |            |              |                |            |         |                     |                                                    |                                                    |                  |
# |           |            |              |                |            |         |                     |I really like the velcro sides. The entire "bla...  |                                                    |                  |
# |           |            |              |                |            |         |                     |                                                    |                                                    |                  |
# |           |            |              |                |            |         |                     |My only concern is the durability of the paddin...  |                                                    |                  |
# |5          |true        |12 28, 2016   |A22VV5OKYSN1HF  |B01H7N27L2  |NULL     |Amazon Customer      |Great product.                                      |Five Stars                                          |1482883200        |
# |5          |true        |12 22, 2016   |AHSBMY0HCIDKO   |B01H7N27L2  |NULL     |guy giusto           |This is a very nice accessory for my lp string ...  |This is a very nice accessory for my lp string ...  |1482364800        |
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Snowpark DataFrame Actions and Transformations

# %% [markdown]
# ##### Access Semi-structured Data using Snowpark DataFrame API

# %%
df_amazon_reviews_movies.select(json_extract_path_text(col('STYLE'), lit('"Format:"')).alias('VALUE')).show()
# Out:
# -----------
# |"VALUE"  |
# -----------
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# | DVD     |
# -----------

# %% [markdown]
# ##### Combine Movies & TV with Musical Instruments Reviews

# %%
df_amazon_reviews_all = df_amazon_reviews_musical_inst.union(df_amazon_reviews_movies)
df_amazon_reviews_all.show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"OVERALL"  |"VERIFIED"  |"REVIEWTIME"  |"REVIEWERID"    |"ASIN"      |"STYLE"  |"REVIEWERNAME"      |"REVIEWTEXT"                                        |"SUMMARY"                                       |"UNIXREVIEWTIME"  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |5          |true        |11 24, 2014   |A3A1S9TTUM5RUR  |B003KISCCW  |NULL     |timguitartaylor     |Doesn't get any better than this!                   |Five Stars                                      |1416787200        |
# |5          |false       |08 29, 2014   |A1HTFH0H09OBWT  |B003KJ0ZD0  |NULL     |Robert Wulf         |Great product for those larger areas. I use min...  |Copper Tone                                     |1409270400        |
# |5          |false       |08 17, 2014   |A158WIQJCLENUM  |B003KJ0ZD0  |NULL     |Patrick Hepburn     |Works great!!!                                      |Five Stars                                      |1408233600        |
# |5          |true        |10 3, 2014    |AZJTGLS9W8RJQ   |B003KXYZYG  |NULL     |Wilfred Tate        |I LOVE IT!  This mouthpiece put me in a new cat...  |I LOVE IT! This mouthpiece put me in a new ...  |1412294400        |
# |5          |true        |04 30, 2013   |A5YSNAPU69BFF   |B000R27VSK  |NULL     |Almost Auntie Mame  |I am terrible at maintaining the correct rhythm...  |Great help                                      |1367280000        |
# |4          |true        |03 10, 2016   |AMIKINEZ0CZE5   |B000QRHA6E  |NULL     |Beverly A. Whelan   |I bought this for my grandson and he took lesso...  |It is a good product for the money              |1457568000        |
# |5          |true        |11 9, 2017    |A2HNEY2CVEAT84  |B00E05BPSW  |NULL     |Delubious           |Does the job.                                       |Five Stars                                      |1510185600        |
# |5          |true        |10 26, 2017   |A10DXLQ7KICQ8U  |B00E05BPSW  |NULL     |Amazon Customer     |For my TEAC reel to reel. It's from the early '...  |Old school audio                                |1508976000        |
# |4          |true        |12 5, 2017    |A1L0SSLBO8UB60  |B004M8UZ3S  |NULL     |santi               |Good!                                               |Four Stars                                      |1512432000        |
# |5          |true        |04 15, 2016   |AWG5SKMWCIHMA   |B004M8UZ3S  |NULL     |TAYLOR F.           |Simple, and gets the job done. I needed a bead ...  |Drum Tap Machine                                |1460678400        |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Replace Missing Values for REVIEWTEXT column with "Not available"

# %%
null_cnt = df_amazon_reviews_all.filter(col("REVIEWTEXT").is_null()).count()
df_amazon_reviews_all = df_amazon_reviews_all.fillna('Not available',subset=["REVIEWTEXT"])
print(f"Number of records with missing REVIEWTEXT column filled with 'Not available':",null_cnt)
print(f"Total records:",df_amazon_reviews_all.count())
# Out:
# Number of records with missing REVIEWTEXT column filled with 'Not available': 8688
# Total records: 10003402

# %% [markdown]
# ### Snowpark Python User-Defined Function (UDF)

# %% [markdown]
# #### Create and Register UDF named "to_lowercase"

# %%
@udf(session=session,name='to_lowercase',replace=True,is_permanent=True,stage_location='@dash_udfs')
def to_lowercase(txt: str) -> str:
    return txt.lower()

# %% [markdown]
# #### Call "to_lowercase" UDF on "SUMMARY" column in Snowpark DataFrame

# %%
df_amazon_reviews_all.select("SUMMARY",call_udf('to_lowercase',col('SUMMARY')).as_('SUMMARY_LOWERCASE')).show()
# Out:
# -----------------------------------------------------------------------------------------------------------
# |"SUMMARY"                                           |"SUMMARY_LOWERCASE"                                 |
# -----------------------------------------------------------------------------------------------------------
# |Five Stars                                          |five stars                                          |
# |Five Stars                                          |five stars                                          |
# |Five Stars                                          |five stars                                          |
# |Five Stars                                          |five stars                                          |
# |Excellent                                           |excellent                                           |
# |Kyser                                               |kyser                                               |
# |They were easy to put on the guitar and my son ...  |they were easy to put on the guitar and my son ...  |
# |Strumming again                                     |strumming again                                     |
# |Great strings for a great price!                    |great strings for a great price!                    |
# |Five Stars                                          |five stars                                          |
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Create and Register Natural Language Processing (NLP) UDF using spaCy and BeautifulSoup

# %%
session.clear_imports()
session.add_import('@dash_udf_imports/en_core_web_sm.zip.gz')

@cached(cache={})
def load_en_core_web_sm(input_file,output_dir)-> object:
    import zipfile
    import spacy
    with zipfile.ZipFile(input_file, 'r') as zip_ref:
        zip_ref.extractall(output_dir)
    # load and return the english language small model of spacy
    nlp = spacy.load(output_dir + "/en_core_web_sm/en_core_web_sm-2.3.0")
    return nlp

@udf(session=session,packages=['spacy==2.3.5','beautifulsoup4','cachetools==4.2.2'],name='batch_nlp_tokenize_text',replace=True,is_permanent=True,stage_location='@dash_udfs')
def batch_nlp_tokenize_text(df: PandasDataFrame[str]) -> PandasSeries[list]:
    import os
    import sys
    import spacy
    from bs4 import BeautifulSoup 
    from spacy.tokenizer import Tokenizer
                       
    IMPORT_DIRECTORY_NAME = "snowflake_import_directory"
    import_dir = sys._xoptions[IMPORT_DIRECTORY_NAME]
    
    input_file = import_dir + 'en_core_web_sm.zip'
    output_dir = '/tmp/en_core_web_sm' + str(os.getpid())
    
    nlp = load_en_core_web_sm(input_file,output_dir)    
    tokenizer = Tokenizer(nlp.vocab)
    
    df.columns = ['REVIEWTEXT']

    # strip html
    df['REVIEWTEXT'] = df['REVIEWTEXT'].apply(lambda txt: BeautifulSoup(txt, "html.parser").get_text())
    
    # tokenize, lemmatize verbs and remove stop words
    df['TOKENS'] = df['REVIEWTEXT'].apply(lambda txt: [t.lemma_ for t in tokenizer(txt) if not t.is_stop])

    return df['TOKENS']

# %% [markdown]
# #### Call NLP UDF on column "REVIEWTEXT" in Snowpark DataFrame to tokenize Amazon Reviews

# %% [markdown]
# ##### Sample Size: 10 records

# %%
df_amazon_reviews_all.select('REVIEWTEXT',call_udf('batch_nlp_tokenize_text',col('REVIEWTEXT')).as_("TOKENS")).limit(10).show()
# Out:
# --------------------------------------------------------------------------
# |"REVIEWTEXT"                                        |"TOKENS"           |
# --------------------------------------------------------------------------
# |Great, still learning the various adjustment        |[                  |
# |                                                    |  "Great,",        |
# |                                                    |  "learn",         |
# |                                                    |  "adjustment"     |
# |                                                    |]                  |
# |Great replacements.                                 |[                  |
# |                                                    |  "Great",         |
# |                                                    |  "replacements."  |
# |                                                    |]                  |
# |I just recently bought this guitar and have rea...  |[                  |
# |                                                    |  "recently",      |
# |The neck is set up different then a traditional...  |  "buy",           |
# |                                                    |  "guitar",        |
# |The Fishman electronics have a great sound to p...  |  "enjoy",         |
# |                                                    |  "play",          |
# |If your looking for a good solid nylon string g...  |  "day",           |
# |                                                    |  "one.",          |
# |Update;                                             |  "start",         |
# |After owning this guitar for over a year, I dec...  |  "decide",        |
# |                                                    |  "Cordoba",       |
# |                                                    |  "Guitar",        |
# |                                                    |  "Center.",       |
# |                                                    |  "long",          |
# |                                                    |  "story",         |
# |                                                    |  "short,",        |
# |                                                    |  "send",          |
# |                                                    |  "defective",     |
# |                                                    |  "guitars.",      |
# |                                                    |  "get",           |
# |                                                    |  "refund,",       |
# |                                                    |  "go",            |
# |                                                    |  "local",         |
# |                                                    |  "music",         |
# |                                                    |  "shop",          |
# |                                                    |  "NS32CE",        |
# |                                                    |  "hang",          |
# |                                                    |  "rack.",         |
# |                                                    |  "chord,",        |
# |                                                    |  "know",          |
# |                                                    |  "guitar",        |
# |                                                    |  "special.",      |
# |                                                    |  "\n\n",          |
# |                                                    |  "neck",          |
# |                                                    |  "set",           |
# |                                                    |  "different",     |
# |                                                    |  "traditional",   |
# |                                                    |  "classical.",    |
# |                                                    |  "play",          |
# |                                                    |  "better.",       |
# |                                                    |  "1/8",           |
# |                                                    |  "narrow",        |
# |                                                    |  "normal",        |
# |                                                    |  "string",        |
# |                                                    |  "space",         |
# |                                                    |  "same.",         |
# |                                                    |  "allow",         |
# |                                                    |  "classical",     |
# |                                                    |  "style",         |
# |                                                    |  "easy",          |
# |                                                    |  "hand",          |
# |                                                    |  "it.",           |
# |                                                    |  "\n\n",          |
# |                                                    |  "Fishman",       |
# |                                                    |  "electronic",    |
# |                                                    |  "great",         |
# |                                                    |  "sound",         |
# |                                                    |  "plug",          |
# |                                                    |  "with.",         |
# |                                                    |  "issue",         |
# |                                                    |  "style",         |
# |                                                    |  "playing.",      |
# |                                                    |  "play",          |
# |                                                    |  "fingernail",    |
# |                                                    |  "transfer",      |
# |                                                    |  "lot",           |
# |                                                    |  "right",         |
# |                                                    |  "hand",          |
# |                                                    |  "string",        |
# |                                                    |  "noise",         |
# |                                                    |  "I'm",           |
# |                                                    |  "plug",          |
# |                                                    |  "in.",           |
# |                                                    |  "little",        |
# |                                                    |  "creative",      |
# |                                                    |  "EQ",            |
# |                                                    |  "work,",         |
# |                                                    |  "easily",        |
# |                                                    |  "overcome.",     |
# |                                                    |  "\n\n",          |
# |                                                    |  "look",          |
# |                                                    |  "good",          |
# |                                                    |  "solid",         |
# |                                                    |  "nylon",         |
# |                                                    |  "string",        |
# |                                                    |  "guitar",        |
# |                                                    |  "afford",        |
# |                                                    |  "price",         |
# |                                                    |  "tag,",          |
# |                                                    |  "Taylor",        |
# |                                                    |  "line",          |
# |                                                    |  "NS",            |
# |                                                    |  "guitar",        |
# |                                                    |  "warm,",         |
# |                                                    |  "invite",        |
# |                                                    |  "tone",          |
# |                                                    |  "sound",         |
# |                                                    |  "beautiful.",    |
# |                                                    |  "way",           |
# |                                                    |  "well",          |
# |                                                    |  "guitar",        |
# |                                                    |  "buy",           |
# |                                                    |  "hand",          |
# |                                                    |  "custom!",       |
# |                                                    |  "\n\n",          |
# |                                                    |  "Update;",       |
# |                                                    |  "\n",            |
# |                                                    |  "own",           |
# |                                                    |  "guitar",        |
# |                                                    |  "year,",         |
# |                                                    |  "decide",        |
# |                                                    |  "change",        |
# |                                                    |  "strings.",      |
# |                                                    |  "long",          |
# |                                                    |  "did,",          |
# |                                                    |  "start",         |
# |                                                    |  "notice",        |
# |                                                    |  "unusual",       |
# |                                                    |  "tightness",     |
# |                                                    |  "string",        |
# |                                                    |  "tuner,",        |
# |                                                    |  "point",         |
# |                                                    |  "jamming.",      |
# |                                                    |  "take",          |
# |                                                    |  "tuner",         |
# |                                                    |  "discover",      |
# |                                                    |  "sleeve",        |
# |                                                    |  "break",         |
# |                                                    |  "rotate",        |
# |                                                    |  "metal",         |
# |                                                    |  "barrel.",       |
# |                                                    |  "take",          |
# |                                                    |  "guitar",        |
# |                                                    |  "buy",           |
# |                                                    |  "Taylor",        |
# |                                                    |  "cover",         |
# |                                                    |  "repair",        |
# |                                                    |  "lifetime",      |
# |                                                    |  "warranty",      |
# |                                                    |  "program!",      |
# |                                                    |  "customer",      |
# |                                                    |  "service",       |
# |                                                    |  "alive",         |
# |                                                    |  "El",            |
# |                                                    |  "Cajon!"         |
# |                                                    |]                  |
# |Beautifully crafted piece of equipment              |[                  |
# |sound clarity is more than expected                 |  "Beautifully",   |
# |                                                    |  "craft",         |
# |would definitely recommend as a excellent addit...  |  "piece",         |
# |                                                    |  "equipment",     |
# |                                                    |  "\n",            |
# |                                                    |  "sound",         |
# |                                                    |  "clarity",       |
# |                                                    |  "expect",        |
# |                                                    |  "\n\n",          |
# |                                                    |  "definitely",    |
# |                                                    |  "recommend",     |
# |                                                    |  "excellent",     |
# |                                                    |  "addition",      |
# |                                                    |  "small",         |
# |                                                    |  "mid",           |
# |                                                    |  "size",          |
# |                                                    |  "large",         |
# |                                                    |  "studio"         |
# |                                                    |]                  |
# |nice gift for the guitar player that has everyt...  |[                  |
# |I tested it on the stock that came with it.  ve...  |  "nice",          |
# |I tested it on an old credit card. it felt good...  |  "gift",          |
# |just needs a bit of sanding about the edge with...  |  "guitar",        |
# |                                                    |  "player",        |
# |                                                    |  "plectrum",      |
# |                                                    |  "maker!",        |
# |                                                    |  "\n",            |
# |                                                    |  "test",          |
# |                                                    |  "stock",         |
# |                                                    |  "come",          |
# |                                                    |  "it.",           |
# |                                                    |  " ",             |
# |                                                    |  "nice.",         |
# |                                                    |  "\n",            |
# |                                                    |  "test",          |
# |                                                    |  "old",           |
# |                                                    |  "credit",        |
# |                                                    |  "card.",         |
# |                                                    |  "feel",          |
# |                                                    |  "good",          |
# |                                                    |  "punch",         |
# |                                                    |  "away",          |
# |                                                    |  "card!",         |
# |                                                    |  "\n",            |
# |                                                    |  "need",          |
# |                                                    |  "bite",          |
# |                                                    |  "sand",          |
# |                                                    |  "edge",          |
# |                                                    |  "include",       |
# |                                                    |  "Emory",         |
# |                                                    |  "board!"         |
# |                                                    |]                  |
# |Really cool idea. Can punch through anything cr...  |[                  |
# |                                                    |  "cool",          |
# |                                                    |  "idea.",         |
# |                                                    |  "punch",         |
# |                                                    |  "credit",        |
# |                                                    |  "card",          |
# |                                                    |  "thickness",     |
# |                                                    |  "pick.",         |
# |                                                    |  "Given",         |
# |                                                    |  "gift",          |
# |                                                    |  "love"           |
# |                                                    |]                  |
# |Excellent                                           |[                  |
# |                                                    |  "Excellent"      |
# |                                                    |]                  |
# |Great product and customer service.                 |[                  |
# |                                                    |  "Great",         |
# |                                                    |  "product",       |
# |                                                    |  "customer",      |
# |                                                    |  "service."       |
# |                                                    |]                  |
# |ok                                                  |[                  |
# |                                                    |  "okay"           |
# |                                                    |]                  |
# |I purchased this based on price alone.  The col...  |[                  |
# |                                                    |  "purchase",      |
# |                                                    |  "base",          |
# |                                                    |  "price",         |
# |                                                    |  "alone.",        |
# |                                                    |  " ",             |
# |                                                    |  "color",         |
# |                                                    |  "loud,",         |
# |                                                    |  "decide",        |
# |                                                    |  "try.",          |
# |                                                    |  " ",             |
# |                                                    |  "look",          |
# |                                                    |  "inexpensive,",  |
# |                                                    |  "light",         |
# |                                                    |  "duty",          |
# |                                                    |  "stand",         |
# |                                                    |  "home",          |
# |                                                    |  "use.",          |
# |                                                    |  " ",             |
# |                                                    |  "product",       |
# |                                                    |  "receive",       |
# |                                                    |  "suprised",      |
# |                                                    |  "me.",           |
# |                                                    |  " ",             |
# |                                                    |  "suit",          |
# |                                                    |  "purpose",       |
# |                                                    |  "fine."          |
# |                                                    |]                  |
# --------------------------------------------------------------------------

# %% [markdown]
# ### Snowpark Python Stored Procedure (SP)

# %% [markdown]
# #### Create Python Function to Transform the Data

# %%
def process_amazon_reviews(session: Session) -> str:
  # Load Movies and TV Reviews
  df_amazon_reviews_movies = session.table('amazon_reviews_movies')

  # Load Musical Instruments Reviews
  df_amazon_reviews_musical_inst = session.table('amazon_reviews_musical_instruments')

  # Combine Movies & TV with Musical Instruments Reviews
  df_amazon_reviews_all = df_amazon_reviews_musical_inst.union(df_amazon_reviews_movies)

  # Replace Missing Values for REVIEWTEXT column with "Not available"
  df_amazon_reviews_all = df_amazon_reviews_all.fillna('Not available',subset=["REVIEWTEXT"])

  # Call NLP UDF on column "REVIEWTEXT" to tokenize Amazon Reviews
  df_amazon_reviews_all = df_amazon_reviews_all.select('*',call_udf('batch_nlp_tokenize_text',col('REVIEWTEXT')).as_("TOKENS"))

  # Save all columns including tokens in a new table
  df_amazon_reviews_all.write.mode('overwrite').save_as_table('AMAZON_REVIEWS_WITH_TOKENS')

  return "SUCCESS"

# %% [markdown]
# #### Register Python Function as Snowpark Stored Procedure to Deploy Code to Snowflake

# %%
# Register function as a Stored Procedure
session.sproc.register(
  func=process_amazon_reviews,
  name="process_amazon_reviews",
  packages=['snowflake-snowpark-python'],
  is_permanent=True,
  stage_location="@dash_sprocs",
  replace=True)

# %% [markdown]
# #### Execute Snowpark Stored Procedure to Transform Data on Snowflake

# %%
print(session.call('process_amazon_reviews'))
# Out:
# SUCCESS

# %% [markdown]
# #### Examine Results - Reviews and Tokens

# %%
df_amazon_reviews_all = session.table('AMAZON_REVIEWS_WITH_TOKENS').select('REVIEWTEXT','TOKENS')
df_amazon_reviews_all.show()
# Out:
# -------------------------------------------------------------------------------
# |"REVIEWTEXT"                                        |"TOKENS"                |
# -------------------------------------------------------------------------------
# |This 3rd installment of the series was disappoi...  |[                       |
# |                                                    |  "3rd",                |
# |                                                    |  "installment",        |
# |                                                    |  "series",             |
# |                                                    |  "disappointing.",     |
# |                                                    |  "Kate",               |
# |                                                    |  "Beckinsale,",        |
# |                                                    |  "remind",             |
# |                                                    |  "3rd",                |
# |                                                    |  "installment",        |
# |                                                    |  "Mummy",              |
# |                                                    |  "series.",            |
# |                                                    |  "definite",           |
# |                                                    |  "come",               |
# |                                                    |  "down."               |
# |                                                    |]                       |
# |Why can't they all just get along? The Vampires...  |[                       |
# |                                                    |  "can't",              |
# |Well I guess it's a good thing for us though, n...  |  "along?",             |
# |                                                    |  "Vampires",           |
# |The main writers of the franchise, Len Wiseman ...  |  "Werewolves",         |
# |                                                    |  "\"at",               |
# |I was also skeptical of Rhona Mitra taking Kate...  |  "throats\"",          |
# |                                                    |  "generation",         |
# |The series documents a war that has been raging...  |  "instead",            |
# |                                                    |  "let",                |
# |All in all the whole series is a very well done...  |  "bygone",             |
# |                                                    |  "bygone",             |
# |Definitely worth the purchase of putting the wh...  |  "team",               |
# |                                                    |  "fee",                |
# |                                                    |  "mere",               |
# |                                                    |  "mortals...I",        |
# |                                                    |  "mean...how",         |
# |                                                    |  "silly,",             |
# |                                                    |  "right?",             |
# |                                                    |  "\n\n",               |
# |                                                    |  "guess",              |
# |                                                    |  "it's",               |
# |                                                    |  "good",               |
# |                                                    |  "thing",              |
# |                                                    |  "though,",            |
# |                                                    |  "no?",                |
# |                                                    |  "war",                |
# |                                                    |  "action-packed",      |
# |                                                    |  "Underworld",         |
# |                                                    |  "series.",            |
# |                                                    |  "There's",            |
# |                                                    |  "suspense,",          |
# |                                                    |  "ton",                |
# |                                                    |  "action",             |
# |                                                    |  "great",              |
# |                                                    |  "storyline",          |
# |                                                    |  "start",              |
# |                                                    |  "prequel",            |
# |                                                    |  "right",              |
# |                                                    |  "Evolution.",         |
# |                                                    |  "\n\n",               |
# |                                                    |  "main",               |
# |                                                    |  "writer",             |
# |                                                    |  "franchise,",         |
# |                                                    |  "Len",                |
# |                                                    |  "Wiseman",            |
# |                                                    |  "(who",               |
# |                                                    |  "direct",             |
# |                                                    |  "two)",               |
# |                                                    |  "Danny",              |
# |                                                    |  "McBride",            |
# |                                                    |  "intact",             |
# |                                                    |  "Rise",               |
# |                                                    |  "Lycans,",            |
# |                                                    |  "that's",             |
# |                                                    |  "key",                |
# |                                                    |  "ingredient",         |
# |                                                    |  "successful",         |
# |                                                    |  "prequel",            |
# |                                                    |  "sequel.",            |
# |                                                    |  "director's",         |
# |                                                    |  "chair",              |
# |                                                    |  "take",               |
# |                                                    |  "FX",                 |
# |                                                    |  "vet",                |
# |                                                    |  "Pat",                |
# |                                                    |  "Totoupolis.",        |
# |                                                    |  "fact",               |
# |                                                    |  "\"real\"",           |
# |                                                    |  "directorial",        |
# |                                                    |  "try",                |
# |                                                    |  "bite",               |
# |                                                    |  "skeptical",          |
# |                                                    |  "go",                 |
# |                                                    |  "Rise",               |
# |                                                    |  "Lycans.",            |
# |                                                    |  "let",                |
# |                                                    |  "tell",               |
# |                                                    |  "you,",               |
# |                                                    |  "Totoupolis",         |
# |                                                    |  "pull",               |
# |                                                    |  "off.",               |
# |                                                    |  "\n\n",               |
# |                                                    |  "skeptical",          |
# |                                                    |  "Rhona",              |
# |                                                    |  "Mitra",              |
# |                                                    |  "take",               |
# |                                                    |  "Kate",               |
# |                                                    |  "Benkensale's",       |
# |                                                    |  "place",              |
# |                                                    |  "lead",               |
# |                                                    |  "lady.",              |
# |                                                    |  "movie",              |
# |                                                    |  "progress",           |
# |                                                    |  "conclude",           |
# |                                                    |  "clear",              |
# |                                                    |  "Mitra",              |
# |                                                    |  "perfect",            |
# |                                                    |  "role.",              |
# |                                                    |  "\n\n",               |
# |                                                    |  "series",             |
# |                                                    |  "document",           |
# |                                                    |  "war",                |
# |                                                    |  "rage",               |
# |                                                    |  "Vampires",           |
# |                                                    |  "Lycans",             |
# |                                                    |  "year",               |
# |                                                    |  "Vampire",            |
# |                                                    |  "leader",             |
# |                                                    |  "didn't",             |
# |                                                    |  "want",               |
# |                                                    |  "Vampire",            |
# |                                                    |  "daughter",           |
# |                                                    |  "gettin'",            |
# |                                                    |  "busy",               |
# |                                                    |  "Wolfman.",           |
# |                                                    |  "Rise",               |
# |                                                    |  "Lycans",             |
# |                                                    |  "kick",               |
# |                                                    |  "off,",               |
# |                                                    |  "leave",              |
# |                                                    |  "room",               |
# |                                                    |  "2",                  |
# |                                                    |  "prequel",            |
# |                                                    |  "Underworld",         |
# |                                                    |  "Evolution.",         |
# |                                                    |  "\n\n",               |
# |                                                    |  "series",             |
# |                                                    |  "story",              |
# |                                                    |  "pay",                |
# |                                                    |  "watch",              |
# |                                                    |  "beginning.",         |
# |                                                    |  "Yes,",               |
# |                                                    |  "stand-alone",        |
# |                                                    |  "potential.",         |
# |                                                    |  "haven't",            |
# |                                                    |  "already,",           |
# |                                                    |  "you'll",             |
# |                                                    |  "fun",                |
# |                                                    |  "rend",               |
# |                                                    |  "purchase",           |
# |                                                    |  "Underworld",         |
# |                                                    |  "Underworld",         |
# |                                                    |  "Evolution",          |
# |                                                    |  "too.",               |
# |                                                    |  "\n\n",               |
# |                                                    |  "Definitely",         |
# |                                                    |  "worth",              |
# |                                                    |  "purchase",           |
# |                                                    |  "putt",               |
# |                                                    |  " ",                  |
# |                                                    |  "Underworld",         |
# |                                                    |  "Trilogy",            |
# |                                                    |  "(Underworld",        |
# |                                                    |  "/",                  |
# |                                                    |  "Underworld:",        |
# |                                                    |  "Evolution",          |
# |                                                    |  "/",                  |
# |                                                    |  "Underworld:",        |
# |                                                    |  "Rise",               |
# |                                                    |  "Lycans)",            |
# |                                                    |  " ",                  |
# |                                                    |  "collection."         |
# |                                                    |]                       |
# |GOOD MOVIE                                          |[                       |
# |                                                    |  "GOOD",               |
# |                                                    |  "MOVIE"               |
# |                                                    |]                       |
# |He was on my mind too girl. lol                     |[                       |
# |                                                    |  "mind",               |
# |                                                    |  "girl.",              |
# |                                                    |  "lol"                 |
# |                                                    |]                       |
# |Item was brand new in package and had never bee...  |[                       |
# |                                                    |  "Item",               |
# |                                                    |  "brand",              |
# |                                                    |  "new",                |
# |                                                    |  "package",            |
# |                                                    |  "opened.",            |
# |                                                    |  "Actually",           |
# |                                                    |  "receive",            |
# |                                                    |  "director",           |
# |                                                    |  "cut",                |
# |                                                    |  "edition",            |
# |                                                    |  "instead",            |
# |                                                    |  "standard",           |
# |                                                    |  "one."                |
# |                                                    |]                       |
# |Got hooked watching this series.  Thought was g...  |[                       |
# |                                                    |  "Got",                |
# |                                                    |  "hook",               |
# |                                                    |  "watch",              |
# |                                                    |  "series.",            |
# |                                                    |  " ",                  |
# |                                                    |  "Thought",            |
# |                                                    |  "go",                 |
# |                                                    |  "bore",               |
# |                                                    |  "vampire/warewolf",   |
# |                                                    |  "story,",             |
# |                                                    |  "different.",         |
# |                                                    |  " ",                  |
# |                                                    |  "bite",               |
# |                                                    |  "violent",            |
# |                                                    |  "faint",              |
# |                                                    |  "heart.",             |
# |                                                    |  " ",                  |
# |                                                    |  "strong,",            |
# |                                                    |  "brave",              |
# |                                                    |  "heroine!"            |
# |                                                    |]                       |
# |My boy friends fav movie combo was a perfect pi...  |[                       |
# |                                                    |  "boy",                |
# |                                                    |  "friend",             |
# |                                                    |  "fav",                |
# |                                                    |  "movie",              |
# |                                                    |  "combo",              |
# |                                                    |  "perfect",            |
# |                                                    |  "pick",               |
# |                                                    |  "father",             |
# |                                                    |  "day!",               |
# |                                                    |  "happy",              |
# |                                                    |  "great",              |
# |                                                    |  "condition."          |
# |                                                    |]                       |
# |Great transaction..Fast shipping...Would recomm...  |[                       |
# |Amazon again in the future.                         |  "Great",              |
# |                                                    |  "transaction..Fast",  |
# |                                                    |  "shipping...Would",   |
# |                                                    |  "recommend",          |
# |                                                    |  "seller!",            |
# |                                                    |  "Product",            |
# |                                                    |  "described,",         |
# |                                                    |  "arrive",             |
# |                                                    |  "quickly.",           |
# |                                                    |  "buy",                |
# |                                                    |  "\n",                 |
# |                                                    |  "Amazon",             |
# |                                                    |  "future."             |
# |                                                    |]                       |
# |I grew up watching this show. It was great to s...  |[                       |
# |                                                    |  "grow",               |
# |                                                    |  "watch",              |
# |                                                    |  "show.",              |
# |                                                    |  "great",              |
# |                                                    |  "again.",             |
# |                                                    |  "DVDs",               |
# |                                                    |  "like",               |
# |                                                    |  "bring",              |
# |                                                    |  "people's",           |
# |                                                    |  "memory",             |
# |                                                    |  "grow",               |
# |                                                    |  "up.",                |
# |                                                    |  "guest",              |
# |                                                    |  "star",               |
# |                                                    |  "script",             |
# |                                                    |  "fine",               |
# |                                                    |  "work."               |
# |                                                    |]                       |
# |Poorly made with cartoon crashes! Soap stars ar...  |[                       |
# |                                                    |  "Poorly",             |
# |                                                    |  "cartoon",            |
# |                                                    |  "crashes!",           |
# |                                                    |  "Soap",               |
# |                                                    |  "star",               |
# |                                                    |  "everywhere!",        |
# |                                                    |  "sceens",             |
# |                                                    |  "sharp,",             |
# |                                                    |  "lack",               |
# |                                                    |  "punch",              |
# |                                                    |  "true",               |
# |                                                    |  "disaster",           |
# |                                                    |  "fans..."             |
# |                                                    |]                       |
# -------------------------------------------------------------------------------
